# %%
from lxml import html
import requests
from bs4 import BeautifulSoup
import re
import time
import pandas as pd
import pickle
import numpy as np

import nltk
import gensim
from unidecode import unidecode

# %% [markdown]
# # Main working parts

# %% [markdown]
# First, need to scrape for the data. In this case, I scrape only for American restaurants in San Francisco, and later hope to get more data.
#
# Cory taught me to use the headers, otherwise sites seem to block me from scraping their data.

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}

url = 'http://sanfrancisco.menupages.com/restaurants/all-areas/all-neighborhoods/american/'
page = requests.get(url,headers=headers)

# %% [markdown]
# I need to scrape for restaurant menus. The first thing I need to do is obtain unique identifiers to append to the menu url to get the data for each restaurant.
#
# After some exploration, I found that the url for each restaurant can be found between the strings "restaurants/" and "/" in the html data. I then managed to use re to extract all the data, and store it in a variable called rests.

# %%
rests = re.findall(r'restaurants/(.+?)/',page.content)

# %% [markdown]
# I then found that there is an entry called advertise in there. I'm not sure how many there are, so I remove anything that looks like advertise and store it in a variable called amrests. I verified that I have 630 results for American restaurants on menupages, and exactly 630 entries in my list.

# %%
regex = re.compile(r"advertise")
amrests = [i for i in rests if not regex.search(i)]

# %% [markdown]
# I then want to obtain the restaurant names. I find that the names lie between the strings " "\'> " and " < / a > " (without the quotations and the spaces). I extract them and store them in a list called names. Once I remove all the empty strings, I verify that there are 630 names in this list as well.
#
# Sanity check later: Ensure all names are unique

# %%
names = re.findall(r'"\'>(.*?)</a>',page.content)
names = [i for i in names if i]

# %% [markdown]
# I then wanted to pull the addresses of the restaurants. I found (somewhat) that these addresses lay between " < br / > " and the pipe symbol " | ". To reference the pipe symbol in re, I had to use a backslash, which took a while to figure out and gives a hint for gotchas in the future.
#
# *I only got 619 addresses, so there is some inconsistency. For now, I think it's ok because for MVP I'm not looking to find the nearest restaurant, just a restaurant. Very important to come back to this later.*

# %%
adds = re.findall(r'<br/> (.+?) \|',page.content)

# %% [markdown]
# Using the menu urls, I scrape the menupages websites and extract the menus. For american restaurants, there are 630 menus and this takes roughly 10 minutes to get through. I store the resuls in a hashtable (dictionary)

# %%
menu_dict = {}
t0 = time.time()

for i in amrests:
    url = 'http://sanfrancisco.menupages.com/restaurants/' + i + '/menu'
    menu_dict[i] = requests.get(url,headers=headers).content
t1 = time.time()
totalt = t1-t0
print totalt

# %% [markdown]
# As a sanity check, I ensure that there are 630 menus

# %%
len(menu_dict)

# %% [markdown]
# I store the messy menu html files in a pandas dataframe

# %%
amrest_df = pd.DataFrame(menu_dict.items())

# %% [markdown]
# With a view towards more categories, I categorize all of these items as American food. However, this will probably not be useful for MVP.

# %%
amrest_df.loc[:,'Type'] = 'American'

# %% [markdown]
# I needed to go home, so I pickled the dataframe, and also the page html content, restuarant urls, names and addresses. On Monday, I modified the dataframe, added names etc

# %%
#zip(amrests,names)
#amrest_df = amrest_df.rename(columns={0:'URL',1:'HTML_Menu'})
#amrest_df['Names'] = amrest_df['URL']
#amrest_df.head()
# name_url_dict = {}
# for i,j in enumerate(amrests):
#     name_url_dict[j] = names[i]
#amrest_df['Names'] = amrest_df['Names'].map(name_url_dict)
amrest_df.tail()

# %%
amrest_df.to_pickle('amrest_df')

# %%
# obj0, obj1, obj2 are created here...
# page_content = page.content
# Saving the objects:
# with open('objs.pickle', 'w') as f:  # Python 3: open(..., 'wb')
#     pickle.dump([page_content, rests, names, adds], f)

# Getting back the objects:
with open('objs.pickle') as f:  # Python 3: open(..., 'rb')
    page_content, rests, names, adds = pickle.load(f)

# %% [markdown]
# *Noise in present manner of data extraction (need to address later)*
#
# 1) Not taking into account the context (sometimes the price is listed as bacon for \$9.49 but really it's meant to be a 2 egg breakfast for \$9.49. This is pertinent in It's Top's Coffee Shop
# menu. Need a better way of handling this in the data
#
# 2) Some prices are in title. When price is non existent, need to pull from title (See It's Top's Coffee Shop House omlettes \$7.95)
#
# 3) Some items have weird pricing (See It's Top's Coffee Shop Side of eggs)
#
# 4) Need to add context (Side of eggs vs breakfast consisting of eggs). This can be obtained from headers.
#
# 5) Can extract more ingredients from description, but this will require manipulation of code to extract headers (see above) and text below headers

# %% [markdown]
# ##### Extracting menu item, description and price from the garbled HTML data

# %%
menu_df_dict ={}

regexp_menu_item = r'<cite>(.+?)</cite>'
el_menu_item = 0
regexp_item_description = r'\xa0(.+?)</th>'
el_item_description = 0
regexp_price = r'\xa0(.+?)\r'
el_price = 1

menu_index_start = 2

for i in range(amrest_df.shape[0]):
    menu_html = amrest_df['HTML_Menu'][i]
    bs_menu = BeautifulSoup(menu_html,'html.parser')
    menu_items_list = bs_menu.find_all('tr')
    
    menu_item_list = createItemList(menu_items_list[menu_index_start:],regexp_menu_item,el_menu_item)
    item_description_list = createItemList(menu_items_list[menu_index_start:],regexp_item_description,el_item_description)
    price_list = createItemList(menu_items_list[menu_index_start:],regexp_price,el_price)
    
    menu_df_dict[amrest_df['URL'][i]] = pd.DataFrame(zip(menu_item_list,item_description_list,price_list),columns=['Menu Item','Item Description','Price'])
    
def createItemList(bsoup_list,regexp,element):
    new_list = []
    for y in [re.findall(regexp,str(x)) for x in bsoup_list]:
        try:
            new_list.append(y[element])
        except:
            new_list.append("")    
    
    return new_list

# %% [markdown]
# ###### Pickle the data

# %%
amrest_df = pd.read_pickle('amrest_df')

# pickle.dump(menu_df_dict, open( "menu_df_dict.p", "wb" ) )

menu_df_dict = pickle.load( open( "menu_df_dict.p", "rb" ) )

# %% [markdown]
# ###### Append the actual restaurant name, and the concatenated menu and item description strings to each menu dataframe that is associated with an individual restaurant

# %%
for i,j in zip(amrest_df['URL'],amrest_df['Names']):
    #menu_df_dict[i]['Menu Item + Description Text'] = menu_df_dict[i]['Menu Item'].map(str) + " " + menu_df_dict[i]['Item Description'].map(str)
    menu_df_dict[i]['Restaurant Name'] = j

# %% [markdown]
# ###### Concatenate the entire dictionary of dataframes together in one "giant" dataframe.

# %%
all_amrests_df = pd.concat(menu_df_dict.values(), ignore_index=True)

# %% [markdown]
# # Save the dateframe. For this week, start from here

# %%
#all_amrests_df.to_pickle('all_amrests_df')
all_amrests_df = pd.read_pickle('all_amrests_df')

# %%
import string
# Remove punctuations
all_amrests_df['desc_list'] = all_amrests_df['Menu Item + Description Text'].apply(lambda x: x.translate(string.maketrans("",""), string.punctuation))
# Tokenize
all_amrests_df['desc_list'] = all_amrests_df['desc_list'].apply(lambda x: x.split())

# %%
# Remove stopwords, make everything lowercase
all_amrests_df['desc_list'] = all_amrests_df['desc_list'].apply(lambda x: [i.lower() for i in x if i.lower() not in nltk.corpus.stopwords.words('english')])

# %%
# Get a list of list of tokens
tokens_list = all_amrests_df.desc_list.tolist()

# Get WordNet Lemmatizer
from nltk.stem.wordnet import WordNetLemmatizer
lmtzr = WordNetLemmatizer()

# Lemmatize the tokens, so run, runs and running are all mapped to run
all_amrests_df['desc_list_lem'] = [[lmtzr.lemmatize(i.decode('utf-8')) for i in x] for x in tokens_list]

# %%
all_amrests_df.head(3)

# %%
# Extract the lemmatized tokens
tokens = all_amrests_df['desc_list_lem'].tolist()

# %%
# Vectorize the tokens using tf-idf

from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer(tokenizer=lambda i:i, lowercase=False)
tfs = tfidf.fit_transform(tokens)

# %%
tfs
with open('tfidfmat.pickle', 'w') as f:  # Python 3: open(..., 'wb')
    pickle.dump(tfs, f)

# %%
all_amrests_df['tfidf_vector'] = [i for i in tfs]

# %%
all_amrests_df.iloc[600].tfidf_vector

# %% [markdown]
# #### Get the cosine similarity between an input documents and the rest of the documents, pull out the top 5 that look the same

# %%
from sklearn.metrics.pairwise import cosine_similarity
from scipy import sparse
# 500 works well
# 300 also works very well
#250
# 40000 is interesting
# 30000 works
# 50 is an example of working poorly

cosine_similarities = cosine_similarity(tfs[2500], tfs).flatten()
related_food_idcs = cosine_similarities.argsort()[::-1][1:6]

#cosine_similarities[related_food_idcs]

print related_food_idcs

all_amrests_df.iloc[related_food_idcs][["Menu Item","Item Description","Restaurant Name"]]

# %%
pd_rest_table.iloc[18724]['Menu Item']

# %%
cosine_similarities.argsort()[::-1][1:6]

# %%
all_amrests_df.iloc[299]['Item Description']

# %% [markdown]
# ##### Store results in a SQL database

# %%
from sqlalchemy import create_engine
from sqlalchemy_utils import database_exists, create_database
import psycopg2

# %%
dbname = 'rest_db'
username = 'harisk87'
pswd = '2PsWrD!'

# %%
engine = create_engine('postgresql://%s:%s@localhost/%s'%(username,pswd,dbname))
print engine.url

# %%
if not database_exists(engine.url):
    create_database(engine.url)
print(database_exists(engine.url))

# %%
#pd_rest_table = pd_rest_table.rename(columns={'MenuItem': 'Menu Item', 'ItemDescription': 'Item Description','RestaurantName' : 'Restaurant Name'})
#pd_rest_table = pd_rest_table.replace({'Restaurant Name': {'It&#39;s Top&#39;s Coffee Shop': 'It\'s Tops Coffee Shop'}})
pd_rest_table.head()

# %%
pd_rest_table['Restaurant Name'] = [x.decode('utf-8') for x in pd_rest_table['Restaurant Name']]
pd_rest_table['Item Description'] = [x.decode('utf-8') for x in pd_rest_table['Item Description']]
pd_rest_table['Menu Item'] = [x.decode('utf-8') for x in pd_rest_table['Menu Item']]

# %%
#pd_rest_table.to_pickle('pd_rest_table')
pd_rest_table = pd.read_pickle('pd_rest_table')
## pd_rest_table contains decoded version of stuff
#pd_rest_table = pd.read_pickle('pd_rest_table')
pd_rest_table.head()

# %%
#pd_rest_table['tfidf_vector'].apply(lambda x: x.todense())
#too big!
pd_rest_table = pd_rest_table[["Menu Item","Item Description","Restaurant Name","Price"]]

# %%
pd_rest_table.to_sql('rest_table', engine, if_exists='replace')

# %%
con = None
con = psycopg2.connect(database = dbname, user = username, host='localhost', password=pswd)

# %%
sql_query = """
SELECT * FROM rest_table;
"""
rest_data_from_sql = pd.read_sql_query(sql_query,con)

# %%
sql_query = """ SELECT DISTINCT "Restaurant Name" FROM rest_table """
test = pd.read_sql_query(sql_query,con)

# %%
test.iloc[1]['Restaurant Name']

# %%
rests = []
#query_results = rest_data_from_sql
query_results = pd_rest_table

# %%
rests = []
for i in range(0,query_results.shape[0]):
    try:
        rests.append(dict(index=query_results.iloc[i]['index'], menu_item=query_results.iloc[i]['Menu Item'], desc=query_results.iloc[i]['Item Description'], name = query_results.iloc[i]['Restaurant Name'], price = query_results.iloc[i]['Price']) )
    except:
        #rests.append(dict(index='Weird codec error', menu_item='Weird codec error', desc='Weird codec error', name = 'Weird codec error', price = 'Weird codec error') )
        print i
        rests = []
        break

# %%
len(rests)

# %%
def encoding_hack(text):
    text_int = text.encode("utf-8")
    out_text = text_int.decode("utf-8").encode('ascii','ignore')
    return out_text

# %%
badidx = []
for i in range(0,query_results.shape[0]):
    index_print = query_results.iloc[i]['index']
    
    try:
        menu_print = query_results.iloc[i]['Menu Item']
        desc_print = query_results.iloc[i]['Item Description']
        name_print = query_results.iloc[i]['Restaurant Name']
        price_print = query_results.iloc[i]['Price']
        
        menu_print = encoding_hack(menu_print)
        desc_print = encoding_hack(desc_print)
        name_print = encoding_hack(name_print)
        price_print = encoding_hack(price_print)
        
    except:
        badidx.append(i)

    

    #rests.append(dict(index=index_print, menu_item=menu_print, desc=desc_print, name=name_print, price=price_print) )

# %%
with open('badidx.pickle', 'w') as f:  # Python 3: open(..., 'wb')
    pickle.dump(badidx, f)

# %%
with open('badidx.pickle') as f:  # Python 3: open(..., 'rb')
    badidx = pickle.load(f)

# %%
pd_rest_table_dropped = query_results[~query_results.index.isin(badidx)]

# %%
pd_rest_table_dropped.to_sql('rest_table', engine, if_exists='replace',index='False')

# %%
pd_rest_table_dropped.loc[903]['Menu Item']

# %%
pd_rest_table.head()

# %%
all_amrests_df[(all_amrests_df['Restaurant Name'] == 'Delancey Street') & (all_amrests_df['Menu Item'] == 'Filet Of Smoked Trout')].index.values[0]

# %%
all_amrests_df.shape

# %%
pd_rest_table.shape

# %%
pd_rest_table[(pd_rest_table['Restaurant Name'] == 'Delancey Street') & (pd_rest_table['Menu Item'] == 'Filet Of Smoked Trout')]

# %%
pd_rest_table.iloc[895]

# %% [markdown]
# # PART 2: ATTEMPT TO GET CLEANER RESULTS

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}

url = 'http://www.allmenus.com/ca/san-francisco/420269-thermidor/menu/'
page = requests.get(url,headers=headers)

# %%
soup= BeautifulSoup(page.text, "lxml")

# %%
url = 'http://www.allmenus.com/ca/san-francisco/-/american/'
page = requests.get(url,headers=headers)

# %%
t0 = time.time()

food_categories = ['german']#['american','american-new','german','french','burgers','deli']#'asianfusion','californian','chinese','dim-sum','sandwiches'

headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}

base_url = url = 'http://www.allmenus.com/ca/san-francisco/'

rest_url_list = []
category_list = []

print 'Scraping for urls'
for fcat in food_categories:
    # Get all the restaurants that food category falls into
    top_page = requests.get(base_url + '-/' + fcat + '/',headers=headers)
    
    # Turn it into a BeautifulSoup object
    top_soup= BeautifulSoup(top_page.text, "lxml")
    all_rest_links = top_soup.findAll("p",{"class","restaurant_name"})
    
    for rest in all_rest_links:
        rest_url_list.append(rest.find('a')['href'])
        category_list.append(fcat)
    
print 'URLs obtained, starting to scrape for menus'
# Out:
# Scraping for urls
# URLs obtained, starting to scrape for menus

# %%
t0 = time.time()

item_list = []
i=1
for url,fcat in zip(rest_url_list,category_list):
    print "Scraping restaurant %d"%(i)
    
    page = requests.get('http://www.allmenus.com'+url,headers=headers)
    soup = BeautifulSoup(page.text, "lxml")
    
    # Extract restaurant name
    name = unidecode(soup.find("h1", {"itemprop":"name"}).text)

    # Extract street address
    saddr = unidecode(soup.find("span",{"itemprop":"streetAddress"}).text)

    # Extract the city
    city = unidecode(soup.find("span",{"itemprop":"addressLocality"}).text)

    # Extract the state
    state = unidecode(soup.find("span",{"itemprop":"addressRegion"}).text)

    # Extract the zip code
    zipc = unidecode(soup.find("span",{"itemprop":"postalCode"}).text)
    
    # Extract yelp rating
    try:
        yelp_rating = float(soup.find("meta",{"itemprop":"ratingValue"})['content'])
    except:
        yelp_rating = None

    # Extract number of yelp reviews
    try:
        num_yelp_reviews = int(soup.find("meta",{"itemprop":"reviewCount"})['content'])
    except:
        num_yelp_reviews = None

    # Get the yelp link
    try:
        yelp_link = soup.find("span",{"class":"review_count"}).find('a')['href']
    except:
        yelp_link = None

    all_categories = soup.find_all("div",{"class":"category"})

    for cat in all_categories:
        category_name = unidecode(cat.find("div",{"class":"category_head"}).h3.text)
        category_description = unidecode(cat.find("div",{"class":"category_head"}).p.text)
    
        all_menu_items_in_category = cat.find_all("li",{"class":"menu_item"})
    
        for menu_item in all_menu_items_in_category:
            item_name = unidecode(menu_item.find("span",{"class":"name"}).text)
            item_description = unidecode(menu_item.find("p",{"class":"description"}).text)
            try:
                item_price = unidecode(menu_item.find("span",{"class":"price"}).text)
            except:
                item_price = []
        
            new_item = {'restaurant_name':name, item_name':item_name,'item_description':item_description,'item_price':item_price,'category_name'
                    :category_name,'category_description':category_description,'street_address':saddr,'city':city,
                    'state':state,'zip':zipc,'full_address':", ".join([saddr,city,state,zipc]),"yelp_rating":yelp_rating,
                   'num_reviews':num_yelp_reviews,'yelp_link':yelp_link,'restaurant_category':fcat}
            item_list.append(new_item)
    i+=1

test_df = pd.DataFrame(item_list)
del item_list
t1 = time.time()
print str(t1-t0) + 'seconds'
# Out:
# Scraping restaurant 1
# Scraping restaurant 2
# Scraping restaurant 3
# Scraping restaurant 4
# Scraping restaurant 5
# Scraping restaurant 6
# Scraping restaurant 7
# Scraping restaurant 8
# Scraping restaurant 9
# Scraping restaurant 10
# Scraping restaurant 11
# Scraping restaurant 12
# Scraping restaurant 13
# Scraping restaurant 14
# Scraping restaurant 15
# Scraping restaurant 16
# Scraping restaurant 17
# 12.60835886seconds

# %%
test_df.groupby
# Out:
#     category_description  category_name           city  \
# 0                            Vorspeisen  San Francisco
# 1                            Vorspeisen  San Francisco
# 2                            Vorspeisen  San Francisco
# 3                            Vorspeisen  San Francisco
# 4                            Vorspeisen  San Francisco
# 5                            Vorspeisen  San Francisco
# 6                            Vorspeisen  San Francisco
# 7                            Vorspeisen  San Francisco
# 8                         Hauptgerichte  San Francisco
# 9                         Hauptgerichte  San Francisco
# 10                        Hauptgerichte  San Francisco
# 11                        Hauptgerichte  San Francisco
# 12                        Hauptgerichte  San Francisco
# 13                                 Soup  San Francisco
# 14                               Salads  San Francisco
# 15                               Salads  San Francisco
# 16                               Salads  San Francisco
# 17                              Burgers  San Francisco
# 18                              Burgers  San Francisco
# 19                              Burgers  San Francisco
# 20                              Burgers  San Francisco
# 21                              Burgers  San Francisco
# 22                              Sausage  San Francisco
# 23                              Sausage  San Francisco
# 24                              Sausage  San Francisco
# 25                              Sausage  San Francisco
# 26                           Appetizers  San Francisco
# 27                           Appetizers  San Francisco
# 28                           Appetizers  San Francisco
# 29                           Appetizers  San Francisco
# ..                   ...            ...            ...
# 934                       On The Bottle  San Francisco
# 935                       On The Bottle  San Francisco
# 936                       On The Bottle  San Francisco
# 937                       On The Bottle  San Francisco
# 938                       On The Bottle  San Francisco
# 939                       On The Bottle  San Francisco
# 940                       On The Bottle  San Francisco
# 941                       On The Bottle  San Francisco
# 942                       On The Bottle  San Francisco
# 943                       On The Bottle  San Francisco
# 944                       On The Bottle  San Francisco
# 945                       On The Bottle  San Francisco
# 946                       On The Bottle  San Francisco
# 947                       On The Bottle  San Francisco
# 948                       On The Bottle  San Francisco
# 949                       On The Bottle  San Francisco
# 950                       On The Bottle  San Francisco
# 951                       On The Bottle  San Francisco
# 952                       On The Bottle  San Francisco
# 953                       On The Bottle  San Francisco
# 954                                 Red  San Francisco
# 955                                 Red  San Francisco
# 956                                 Red  San Francisco
# 957                                 Red  San Francisco
# 958                                 Red  San Francisco
# 959                               White  San Francisco
# 960                               White  San Francisco
# 961                               White  San Francisco
# 962                               White  San Francisco
# 963                               White  San Francisco
#
#                                  full_address  \
# 0     525 Laguna St, San Francisco, CA, 94102
# 1     525 Laguna St, San Francisco, CA, 94102
# 2     525 Laguna St, San Francisco, CA, 94102
# 3     525 Laguna St, San Francisco, CA, 94102
# 4     525 Laguna St, San Francisco, CA, 94102
# 5     525 Laguna St, San Francisco, CA, 94102
# 6     525 Laguna St, San Francisco, CA, 94102
# 7     525 Laguna St, San Francisco, CA, 94102
# 8     525 Laguna St, San Francisco, CA, 94102
# 9     525 Laguna St, San Francisco, CA, 94102
# 10    525 Laguna St, San Francisco, CA, 94102
# 11    525 Laguna St, San Francisco, CA, 94102
# 12    525 Laguna St, San Francisco, CA, 94102
# 13   731 Clement St, San Francisco, CA, 94118
# 14   731 Clement St, San Francisco, CA, 94118
# 15   731 Clement St, San Francisco, CA, 94118
# 16   731 Clement St, San Francisco, CA, 94118
# 17   731 Clement St, San Francisco, CA, 94118
# 18   731 Clement St, San Francisco, CA, 94118
# 19   731 Clement St, San Francisco, CA, 94118
# 20   731 Clement St, San Francisco, CA, 94118
# 21   731 Clement St, San Francisco, CA, 94118
# 22   731 Clement St, San Francisco, CA, 94118
# 23   731 Clement St, San Francisco, CA, 94118
# 24   731 Clement St, San Francisco, CA, 94118
# 25   731 Clement St, San Francisco, CA, 94118
# 26   731 Clement St, San Francisco, CA, 94118
# 27   731 Clement St, San Francisco, CA, 94118
# 28   731 Clement St, San Francisco, CA, 94118
# 29   731 Clement St, San Francisco, CA, 94118
# ..                                        ...
# 934  1813 Fulton St, San Francisco, CA, 94117
# 935  1813 Fulton St, San Francisco, CA, 94117
# 936  1813 Fulton St, San Francisco, CA, 94117
# 937  1813 Fulton St, San Francisco, CA, 94117
# 938  1813 Fulton St, San Francisco, CA, 94117
# 939  1813 Fulton St, San Francisco, CA, 94117
# 940  1813 Fulton St, San Francisco, CA, 94117
# 941  1813 Fulton St, San Francisco, CA, 94117
# 942  1813 Fulton St, San Francisco, CA, 94117
# 943  1813 Fulton St, San Francisco, CA, 94117
# 944  1813 Fulton St, San Francisco, CA, 94117
# 945  1813 Fulton St, San Francisco, CA, 94117
# 946  1813 Fulton St, San Francisco, CA, 94117
# 947  1813 Fulton St, San Francisco, CA, 94117
# 948  1813 Fulton St, San Francisco, CA, 94117
# 949  1813 Fulton St, San Francisco, CA, 94117
# 950  1813 Fulton St, San Francisco, CA, 94117
# 951  1813 Fulton St, San Francisco, CA, 94117
# 952  1813 Fulton St, San Francisco, CA, 94117
# 953  1813 Fulton St, San Francisco, CA, 94117
# 954  1813 Fulton St, San Francisco, CA, 94117
# 955  1813 Fulton St, San Francisco, CA, 94117
# 956  1813 Fulton St, San Francisco, CA, 94117
# 957  1813 Fulton St, San Francisco, CA, 94117
# 958  1813 Fulton St, San Francisco, CA, 94117
# 959  1813 Fulton St, San Francisco, CA, 94117
# 960  1813 Fulton St, San Francisco, CA, 94117
# 961  1813 Fulton St, San Francisco, CA, 94117
# 962  1813 Fulton St, San Francisco, CA, 94117
# 963  1813 Fulton St, San Francisco, CA, 94117
#
#                                       item_description  \
# 0                      Traditional Bavarian Cheese mix
# 1
# 2
# 3    Served with cabbage, carrots, beets, potato sa...
# 4
# 5                     Served with homemade apple sauce
# 6    Served with pork and vegetables served with mu...
# 7    Served with sour cream, onions, pickles & pota...
# 8           Served with roasted potatoes & green salad
# 9                    Served with red cabbage & spatzle
# 10           Served with onion sauce & mashed potatoes
# 11            Served with sauerkraut & mashed potatoes
# 12                     Served with a small mixed salad
# 13
# 14   local tomatoes, cucumbers, red onions made wit...
# 15       traditional garlic croutons & parmesan cheese
# 16   garden salad, tomato, crisp bacon, chicken bre...
# 17   served with french fries, lettuce, tomato & onion
# 18              build your own - add bacon or mushroom
# 19   veggie burger with cayenne pepper & cumin with...
# 20       best mix of beef & pork, served with crackers
# 21   cod fillets french fried served with slaw & vi...
# 22   served with sauerkraut and potatoes plenty of ...
# 23                 served with sauerkraut and potatoes
# 24   breast of chicken on a toasted bun, red onions...
# 25   breaded pork tenderloin served with potatoes &...
# 26
# 27           prepared with beer batter & honey mustard
# 28   prepared on sourdough, brushed in olive oil, f...
# 29   lightly fried & served with lemon, cocktail sa...
# ..                                                 ...
# 934                                     porter, latvia
# 935                                      lager, poland
# 936                                       strong lager
# 937                                      lager, poland
# 938                                      lager, poland
# 939                                     porter, poland
# 940                                      lager, poland
# 941                               strong lager, poland
# 942                           hop pearl. lager, poland
# 943                               bock, czech republic
# 944                         dark lager, czech republic
# 945                        double bock, czech republic
# 946                         dark lager, czech republic
# 947                                      kolsch, lager
# 948                                   pilsner, croatia
# 949                                hefeweisen, austria
# 950                                     lager, germany
# 951                               double bock, germany
# 952                         lemon soda, lager, austria
# 953                                 amber ale, germany
# 954                          cabernet sauvignon, chile
# 955                                         merlot, ca
# 956                                         shiraz, ca
# 957                                 pinot noir, france
# 958
# 959                                     chardonnay, ca
# 960                                sauvignon blanc, ca
# 961                                       riesling, wa
# 962                                pinot blanc, france
# 963
#
#                                   item_name item_price  num_reviews  \
# 0                      Pretzel with Obatzda      $8.00       2817.0
# 1                    fresh Bread and Butter      $3.00       2817.0
# 2                           Soup of the Day      $8.00       2817.0
# 3                        Mixed German Salad     $11.00       2817.0
# 4                                   Pretzel      $4.00       2817.0
# 5                           Potato Pancakes     $12.00       2817.0
# 6                     German Ravioli Filled     $14.50       2817.0
# 7                           Pickled Herring     $12.50       2817.0
# 8    Sour Cream, Onions, Pickles & Potatoes     $19.50       2817.0
# 9        Sauteed Porkloin in Mushroom Sauce     $21.50       2817.0
# 10              Meatloaf with Bacon and Egg     $19.50       2817.0
# 11                     Grilled Pork Sausage     $20.00       2817.0
# 12     Cheese Spatzle in Onion Butter Sauce     $18.50       2817.0
# 13                          Soup Of The Day      $4.00         34.0
# 14                              Mixed Green      $4.00         34.0
# 15                             Caesar Salad      $6.00         34.0
# 16                               Cobb Salad      $8.00         34.0
# 17                  Hamburger, Cheeseburger      $8.00         34.0
# 18                  Hamburger, Cheeseburger      $9.50         34.0
# 19                            Garden Burger     $10.00         34.0
# 20                          Louisiana Chili      $8.00         34.0
# 21                             Fish & Chips      $8.00         34.0
# 22                               Weisswurst      $8.00         34.0
# 23                                Bratwurst      $8.00         34.0
# 24                         Chicken Sandwich      $8.00         34.0
# 25                         Weiner Schnitzel     $10.00         34.0
# 26                          Soup Of The Day      $6.00         34.0
# 27                                   Shrimp      $9.00         34.0
# 28                               Bruschetta      $5.00         34.0
# 29                                 Calamari      $8.00         34.0
# ..                                      ...        ...          ...
# 934                        Aldaris Porteris      $6.00        274.0
# 935                                   Warka      $6.00        274.0
# 936                            Warka Strong      $6.00        274.0
# 937                                   Tatra      $6.00        274.0
# 938                         Zywiec Original      $6.00        274.0
# 939                           Zywiec Porter      $6.00        274.0
# 940                               Okocim OK      $6.00        274.0
# 941                          Hevelius Kaper      $6.00        274.0
# 942                         Perla Chmielowa      $6.00        274.0
# 943                        Primator Maibock      $6.00        274.0
# 944                        Primator Premium      $6.00        274.0
# 945                                Primator      $7.00        274.0
# 946                           Bakalar Amber      $6.00        274.0
# 947                             Fruh Kolsch      $6.00        274.0
# 948                              Karlovacko      $6.00        274.0
# 949                           Stiegl Weisse      $6.00        274.0
# 950                Augustinerbrau Edelstoff      $5.00        274.0
# 951                Augustinerbrau Maximator      $6.00        274.0
# 952                           Stiegl Radler      $5.00        274.0
# 953                         Hovels Original      $4.00        274.0
# 954                                  Batitu      $7.00        274.0
# 955                             Quail Creek      $7.00        274.0
# 956                             Quail Creek      $7.00        274.0
# 957                                 Camelot      $8.00        274.0
# 958                               House Red      $5.00        274.0
# 959                                  Bistro      $6.00        274.0
# 960                             Quail Creek      $7.00        274.0
# 961                               Hedgeline      $8.00        274.0
# 962                            Gisselbrecht      $8.00        274.0
# 963                             House White      $5.00        274.0
#
#     restaurant_category state  street_address  \
# 0                german    CA   525 Laguna St
# 1                german    CA   525 Laguna St
# 2                german    CA   525 Laguna St
# 3                german    CA   525 Laguna St
# 4                german    CA   525 Laguna St
# 5                german    CA   525 Laguna St
# 6                german    CA   525 Laguna St
# 7                german    CA   525 Laguna St
# 8                german    CA   525 Laguna St
# 9                german    CA   525 Laguna St
# 10               german    CA   525 Laguna St
# 11               german    CA   525 Laguna St
# 12               german    CA   525 Laguna St
# 13               german    CA  731 Clement St
# 14               german    CA  731 Clement St
# 15               german    CA  731 Clement St
# 16               german    CA  731 Clement St
# 17               german    CA  731 Clement St
# 18               german    CA  731 Clement St
# 19               german    CA  731 Clement St
# 20               german    CA  731 Clement St
# 21               german    CA  731 Clement St
# 22               german    CA  731 Clement St
# 23               german    CA  731 Clement St
# 24               german    CA  731 Clement St
# 25               german    CA  731 Clement St
# 26               german    CA  731 Clement St
# 27               german    CA  731 Clement St
# 28               german    CA  731 Clement St
# 29               german    CA  731 Clement St
# ..                  ...   ...             ...
# 934              german    CA  1813 Fulton St
# 935              german    CA  1813 Fulton St
# 936              german    CA  1813 Fulton St
# 937              german    CA  1813 Fulton St
# 938              german    CA  1813 Fulton St
# 939              german    CA  1813 Fulton St
# 940              german    CA  1813 Fulton St
# 941              german    CA  1813 Fulton St
# 942              german    CA  1813 Fulton St
# 943              german    CA  1813 Fulton St
# 944              german    CA  1813 Fulton St
# 945              german    CA  1813 Fulton St
# 946              german    CA  1813 Fulton St
# 947              german    CA  1813 Fulton St
# 948              german    CA  1813 Fulton St
# 949              german    CA  1813 Fulton St
# 950              german    CA  1813 Fulton St
# 951              german    CA  1813 Fulton St
# 952              german    CA  1813 Fulton St
# 953              german    CA  1813 Fulton St
# 954              german    CA  1813 Fulton St
# 955              german    CA  1813 Fulton St
# 956              german    CA  1813 Fulton St
# 957              german    CA  1813 Fulton St
# 958              german    CA  1813 Fulton St
# 959              german    CA  1813 Fulton St
# 960              german    CA  1813 Fulton St
# 961              german    CA  1813 Fulton St
# 962              german    CA  1813 Fulton St
# 963              german    CA  1813 Fulton St
#
#                                              yelp_link  yelp_rating    zip
# 0    http://www.yelp.com/biz/suppenk%C3%BCche-san-f...          4.0  94102
# 1    http://www.yelp.com/biz/suppenk%C3%BCche-san-f...          4.0  94102
# 2    http://www.yelp.com/biz/suppenk%C3%BCche-san-f...          4.0  94102
# 3    http://www.yelp.com/biz/suppenk%C3%BCche-san-f...          4.0  94102
# 4    http://www.yelp.com/biz/suppenk%C3%BCche-san-f...          4.0  94102
# 5    http://www.yelp.com/biz/suppenk%C3%BCche-san-f...          4.0  94102
# 6    http://www.yelp.com/biz/suppenk%C3%BCche-san-f...          4.0  94102
# 7    http://www.yelp.com/biz/suppenk%C3%BCche-san-f...          4.0  94102
# 8    http://www.yelp.com/biz/suppenk%C3%BCche-san-f...          4.0  94102
# 9    http://www.yelp.com/biz/suppenk%C3%BCche-san-f...          4.0  94102
# 10   http://www.yelp.com/biz/suppenk%C3%BCche-san-f...          4.0  94102
# 11   http://www.yelp.com/biz/suppenk%C3%BCche-san-f...          4.0  94102
# 12   http://www.yelp.com/biz/suppenk%C3%BCche-san-f...          4.0  94102
# 13   http://www.yelp.com/biz/burma-tea-leaf-san-fra...          4.0  94118
# 14   http://www.yelp.com/biz/burma-tea-leaf-san-fra...          4.0  94118
# 15   http://www.yelp.com/biz/burma-tea-leaf-san-fra...          4.0  94118
# 16   http://www.yelp.com/biz/burma-tea-leaf-san-fra...          4.0  94118
# 17   http://www.yelp.com/biz/burma-tea-leaf-san-fra...          4.0  94118
# 18   http://www.yelp.com/biz/burma-tea-leaf-san-fra...          4.0  94118
# 19   http://www.yelp.com/biz/burma-tea-leaf-san-fra...          4.0  94118
# 20   http://www.yelp.com/biz/burma-tea-leaf-san-fra...          4.0  94118
# 21   http://www.yelp.com/biz/burma-tea-leaf-san-fra...          4.0  94118
# 22   http://www.yelp.com/biz/burma-tea-leaf-san-fra...          4.0  94118
# 23   http://www.yelp.com/biz/burma-tea-leaf-san-fra...          4.0  94118
# 24   http://www.yelp.com/biz/burma-tea-leaf-san-fra...          4.0  94118
# 25   http://www.yelp.com/biz/burma-tea-leaf-san-fra...          4.0  94118
# 26   http://www.yelp.com/biz/burma-tea-leaf-san-fra...          4.0  94118
# 27   http://www.yelp.com/biz/burma-tea-leaf-san-fra...          4.0  94118
# 28   http://www.yelp.com/biz/burma-tea-leaf-san-fra...          4.0  94118
# 29   http://www.yelp.com/biz/burma-tea-leaf-san-fra...          4.0  94118
# ..                                                 ...          ...    ...
# 934  http://www.yelp.com/biz/bistro-gambrinus-san-f...          4.0  94117
# 935  http://www.yelp.com/biz/bistro-gambrinus-san-f...          4.0  94117
# 936  http://www.yelp.com/biz/bistro-gambrinus-san-f...          4.0  94117
# 937  http://www.yelp.com/biz/bistro-gambrinus-san-f...          4.0  94117
# 938  http://www.yelp.com/biz/bistro-gambrinus-san-f...          4.0  94117
# 939  http://www.yelp.com/biz/bistro-gambrinus-san-f...          4.0  94117
# 940  http://www.yelp.com/biz/bistro-gambrinus-san-f...          4.0  94117
# 941  http://www.yelp.com/biz/bistro-gambrinus-san-f...          4.0  94117
# 942  http://www.yelp.com/biz/bistro-gambrinus-san-f...          4.0  94117
# 943  http://www.yelp.com/biz/bistro-gambrinus-san-f...          4.0  94117
# 944  http://www.yelp.com/biz/bistro-gambrinus-san-f...          4.0  94117
# 945  http://www.yelp.com/biz/bistro-gambrinus-san-f...          4.0  94117
# 946  http://www.yelp.com/biz/bistro-gambrinus-san-f...          4.0  94117
# 947  http://www.yelp.com/biz/bistro-gambrinus-san-f...          4.0  94117
# 948  http://www.yelp.com/biz/bistro-gambrinus-san-f...          4.0  94117
# 949  http://www.yelp.com/biz/bistro-gambrinus-san-f...          4.0  94117
# 950  http://www.yelp.com/biz/bistro-gambrinus-san-f...          4.0  94117
# 951  http://www.yelp.com/biz/bistro-gambrinus-san-f...          4.0  94117
# 952  http://www.yelp.com/biz/bistro-gambrinus-san-f...          4.0  94117
# 953  http://www.yelp.com/biz/bistro-gambrinus-san-f...          4.0  94117
# 954  http://www.yelp.com/biz/bistro-gambrinus-san-f...          4.0  94117
# 955  http://www.yelp.com/biz/bistro-gambrinus-san-f...          4.0  94117
# 956  http://www.yelp.com/biz/bistro-gambrinus-san-f...          4.0  94117
# 957  http://www.yelp.com/biz/bistro-gambrinus-san-f...          4.0  94117
# 958  http://www.yelp.com/biz/bistro-gambrinus-san-f...          4.0  94117
# 959  http://www.yelp.com/biz/bistro-gambrinus-san-f...          4.0  94117
# 960  http://www.yelp.com/biz/bistro-gambrinus-san-f...          4.0  94117
# 961  http://www.yelp.com/biz/bistro-gambrinus-san-f...          4.0  94117
# 962  http://www.yelp.com/biz/bistro-gambrinus-san-f...          4.0  94117
# 963  http://www.yelp.com/biz/bistro-gambrinus-san-f...          4.0  94117
#
# [964 rows x 14 columns]
