# %%
from lxml import html
import requests
from bs4 import BeautifulSoup
import re
import time
import pandas as pd
import cPickle as pickle
import numpy as np

import nltk
import gensim
from unidecode import unidecode
import string

from sklearn.metrics.pairwise import cosine_similarity
from scipy import sparse
import random 

from matplotlib import pyplot as plt
import seaborn as sns
% matplotlib inline

# %%
#all_menus.to_pickle('all_menus.p')
all_menus = pd.read_pickle('all_menus.p')

#full_menus = all_menus.groupby('name_and_address').agg({'tokens': 'sum'}).reset_index()
#full_menus.to_pickle('full_menus.p')
full_menus = pd.read_pickle('full_menus.p')

# pickle.dump(tokens, open( "old_tokens.p", "wb" ) )
# old_tokens was obtained by removing punctuation, tokenizing, lemmatizing, making lower case and removing duplicate
# words from items in menu
old_tokens = pickle.load(open( "old_tokens.p", "rb" ))

# pickle.dump(new_tokens, open( "new_tokens.p", "wb" ) )
# new_tokens are the tokens gotten from taking old_tokens and
# a) removing words that only appear once in corpus and
# b) removing single letters and c) removing numbers
new_tokens = pickle.load(open( "new_tokens.p", "rb" ))

# pickle.dump(tfidf_mat_menus, open( "tfidf_mat_menus.p", "wb" ) )
tfidf_mat_menus = pickle.load(open( "tfidf_mat_menus.p", "rb" ) )

#pickle.dump(tfidf_mat_rests, open( "tfidf_mat_rests.p", "wb" ) )
tfidf_mat_rests = pickle.load(open( "tfidf_mat_rests.p", "rb" ) )

# pickle.dump(unique_rest_id_list, open( "unique_rest_id_list.p", "wb" ) )
unique_rest_id_list = pickle.load(open( "unique_rest_id_list.p", "rb" ))

#pickle.dump(restaurant_name_list, open( "restaurant_name_list.p", "wb" ) )
restaurant_name_list = pickle.load(open( "restaurant_name_list.p", "rb" ) )

#pickle.dump(restaurant_address_list, open( "restaurant_address_list.p", "wb" ) )
restaurant_address_list = pickle.load(open( "restaurant_address_list.p", "rb" ) )

#pickle.dump(name_and_addr_list, open( "name_and_addr_list.p", "wb" ) )
name_and_addr_list = pickle.load(open( "name_and_addr_list.p", "rb" ) )

# pickle.dump(cos_sim_list, open( "cos_sim_list.p", "wb" ) )
cos_sim_list = pickle.load(open( "cos_sim_list.p", "rb" ) )

# pickle.dump(cost_sim_const_list, open( "cost_sim_const_list.p", "wb" ) )
cost_sim_const_list = pickle.load(open( "cost_sim_const_list.p", "rb" ) )

# pickle.dump(lift_list, open( "lift_list", "wb" ) )
lift_list = pickle.load(open( "lift_list", "rb" ) )

def tfIdfMatCreator(tokens):

    from sklearn.feature_extraction.text import TfidfVectorizer

    tfidf_model = TfidfVectorizer(tokenizer=lambda i:i, lowercase=False)
    tfidf_mat = tfidf_model.fit_transform(tokens)
    return tfidf_mat

def getTopMatches(tfidf_mat,idx):
    
    # Compute the cosine similarity between the input idx and all the other vectors
    cosine_similarities = cosine_similarity(tfidf_mat[idx], tfidf_mat).flatten()

    # Organize the related food in descending order
    related_idcs = cosine_similarities.argsort()[::-1]
    
    # Organize the cosine similarities in descending order
    cosine_similarities_sorted = sorted(cosine_similarities, reverse=True)

    # Remove the user input
    user_selection = related_idcs[0]

    # The rest of them
    other_similar_items = related_idcs[1:]
    
    # Similarity metrics
    return user_selection,other_similar_items,cosine_similarities_sorted[1:]

# %%
jshack_idcs = all_menus[all_menus.restaurant_name=='J Shack'].index.tolist()

sinbad_idcs = all_menus[all_menus.restaurant_name=='Sinbad\'s'].index.tolist()

triptych_idcs = all_menus[all_menus.restaurant_name=='Triptych'].index.tolist()

# %%
idcs_to_drop = sinbad_idcs+triptych_idcs+jshack_idcs

# %%
idcs_to_keep = [x for x in range(all_menus.shape[0]) if x not in idcs_to_drop]

# %%
all_menus_new = all_menus.iloc[idcs_to_keep].reset_index()

# %%
new_tokens_new = [j for i,j in enumerate(new_tokens) if i not in idcs_to_drop]

# %%
all_menus_new.tokens = new_tokens_new

# %%
print all_menus.iloc[12431].item_description
print all_menus.iloc[12431].tokens
# Out:
# juicy all white breast of turkey with mayo, onion, lettuce and tomato
# [u'turkey', u'tomato', u'onion', u'mayo', u'juicy', u'lettuce', u'breast', u'white']

# %%
name_and_addr_list
# Out:
# ['1300 on Filmore, 1300 Fillmore St, San Francisco, CA, 94115',
#  '1760, 1760 Polk St, San Francisco, CA, 94109',
#  '18th Hour Cafe, 3674 18th St, San Francisco, CA, 94110',
#  '20 Spot (Twenty Spot), 3565 20th St, San Francisco, CA, 94110',
#  '21st Amendment Brewery Cafe, 563 2nd St, San Francisco, CA, 94107',
#  '398 Restaurant & Bar, 398 Geary St, San Francisco, CA, 94102',
#  '3rd Street Grill, 695 3rd St, San Francisco, CA, 94107',
#  '4505 Burgers & BBQ, 705 Divisadero St, San Francisco, CA, 94117',
#  '4505 Meats, Location Varies, San Francisco, CA, 94110',
#  '456 Deli & Cafe, 456 Montgomery St, San Francisco, CA, 94104',
#  'A Table, 101 Spear St, San Francisco, CA, 94105',
#  'ABC Bakery Cafe, 2500 Noriega St, San Francisco, CA, 94122',
#  'ABC Bakery Cafe, 650 Jackson St, San Francisco, CA, 94108',
#  'AG Ferrari Foods, 3490 California St, San Francisco, CA, 94118',
#  'AG Ferrari Foods, 688 Mission St, San Francisco, CA, 94105',
#  'AK Subs, 397 8th St, San Francisco, CA, 94103',
#  'AQ, 1085 Mission St, San Francisco, CA, 94103',
#  'Absinthe, 398 Hayes St, San Francisco, CA, 94102',
#  'Akiba, 3141 Clement St, San Francisco, CA, 94121',
#  'Alamo Square Seafood Grill, 803 Fillmore St, San Francisco, CA, 94117',
#  "Alfred's Steakhouse, 659 Merchant St, San Francisco, CA, 94111",
#  'Alibi, 142 Minna St, San Francisco, CA, 94105',
#  'Aliment, 786 Bush St, San Francisco, CA, 94108',
#  'Alimento, 507 Columbus Ave, San Francisco, CA, 94133',
#  'All Star Cafe, 550 Market St, San Francisco, CA, 94104',
#  'Allstar Donuts & Burgers, 290 Golden Gate Ave, San Francisco, CA, 94102',
#  'Alta CA, 1420 Market St, San Francisco, CA, 94103',
#  'Ame, 689 Mission St, San Francisco, CA, 94105',
#  'Amelie, 1754 Polk St, San Francisco, CA, 94109',
#  'American Cafe , 955 Market Street, San Francisco, CA, 94103',
#  'American Cupcake, 1919 Union St, San Francisco, CA, 94123',
#  'American Eatery, Ferry Plaza, San Francisco, CA, 94111',
#  "Anabelle's Bar & Bistro, 68 4th St, San Francisco, CA, 94103",
#  'Anchor & Hope, 83 Minna St, San Francisco, CA, 94105',
#  'Andersen Bakery, 665 Market St, San Francisco, CA, 94105',
#  "Andronico's Deli & Market, 1200 Irving St, San Francisco, CA, 94122",
#  "Angelina's Cafe & Deli, 6000 California St, San Francisco, CA, 94121",
#  "Anna's Teriyaki, 83 9th St, San Francisco, CA, 94103",
#  "Annabelle's Bar & Bistro, 68 4th St, San Francisco, CA, 94103",
#  "Annie's Hot Dogs & Pretzels, 899 Market St, San Francisco, CA, 94105",
#  "Applebee's, 2770 Taylor St, San Francisco, CA, 94133",
#  'Aquitaine, 175 Sutter St, San Francisco, CA, 94104',
#  'Aracely, 1201 8th St, San Francisco, CA, 94107',
#  "Arby's, 1581 Sloat Blvd, San Francisco, CA, 94132",
#  'Archive Bar & Kitchen, 602 Mission St, San Francisco, CA, 94105',
#  'Arguello Super Market, 782 Arguello Blvd, San Francisco, CA, 94118',
#  "Art's Cafe, 747 Irving St, San Francisco, CA, 94122",
#  'Atlas Cafe, 3049 20th St, San Francisco, CA, 94110',
#  'Aurea, 905 California St, San Francisco, CA, 94108',
#  "Avedano's, 237 Cortland Ave, San Francisco, CA, 94110",
#  'B Restaurant and Bar, 720 Howard St, San Francisco, CA, 94103',
#  'B Star, 410 Cortland Ave, San Francisco, CA, 94110',
#  'BIX, 56 Gold St, San Francisco, CA, 94133',
#  'Baby Blues BBQ, 3149 Mission St, San Francisco, CA, 94110',
#  'Bacon Bacon, 205 A Frederick St, San Francisco, CA, 94117',
#  'Baker Street Bistro, 2953 Baker St, San Francisco, CA, 94123',
#  'Balancoire, 2565 Mission St, San Francisco, CA, 94110',
#  'Balboa Cafe, 3199 Fillmore St, San Francisco, CA, 94123',
#  'Balcony Bar at Sundance Kabuki Cinema, 1865 Post St, San Francisco, CA, 94115',
#  'Bar 333 & Bistro, 333 Battery St, San Francisco, CA, 94111',
#  'Bar 888, 888 Howard St, San Francisco, CA, 94103',
#  'Bar Agricole, 355 11th St, San Francisco, CA, 94103',
#  'Bar Jules, 609 Hayes St, San Francisco, CA, 94102',
#  'Bar Tartine, 561 Valencia St, San Francisco, CA, 94110',
#  "Barney's Gourmet Hamburgers, 3344 Steiner St, San Francisco, CA, 94123",
#  "Barney's Gourmet Hamburgers, 4138 24th St, San Francisco, CA, 94114",
#  'Bartlett Hall, 242 OFarrell St, San Francisco, CA, 94102',
#  'Baskin-Robbins, 1539 Sloat Blvd, San Francisco, CA, 94132',
#  'Baskin-Robbins, 2250 Irving St, San Francisco, CA, 94122',
#  'Bay Watch Restaurant, 2150 Lombard St, San Francisco, CA, 94123',
#  'Beach Chalet, 1000 Great Hwy, San Francisco, CA, 94121',
#  'Beach Street Grill, 380 Beach St, San Francisco, CA, 94133',
#  'Beachside, 4300 Judah St, San Francisco, CA, 94122',
#  'Bean Bag Cafe, 601 Divisadero St, San Francisco, CA, 94117',
#  'Beautifull, 3401 California St, San Francisco, CA, 94118',
#  "Bechelli's Flower Market Cafe, 698 Brannan St, San Francisco, CA, 94107",
#  "Beep's Burgers, 1051 Ocean Ave, San Francisco, CA, 94112",
#  'Belly Burgers, 5740 Geary Blvd, San Francisco, CA, 94121',
#  'Belmar - La Gallinita, 2989 24th St, San Francisco, CA, 94110',
#  "Ben & Jerry's, 79 Jefferson St, San Francisco, CA, 94133",
#  "Bender's Bar & Grill, 806 S Van Ness Ave, San Francisco, CA, 94110",
#  'Bergerac, 316 11th St, San Francisco, CA, 94103',
#  'Bernal Star, 410 Cortland Ave, San Francisco, CA, 94110',
#  'Bi-Rite Market, 3639 18th St, San Francisco, CA, 94110',
#  'Bi-Rite Market, 550 Divisadero St, San Francisco, CA, 94117',
#  'Biergarten, 424 Octavia Blvd, San Francisco, CA, 94102',
#  'Big 4 ( Big Four), 1075 California St, San Francisco, CA, 94108',
#  "Big Chef Tom's Belly Burgers, 1550 Howard St, San Francisco, CA, 94103",
#  'Big Mouth Burgers, 3392 24th St, San Francisco, CA, 94110',
#  "Bill's Place, 2315 Clement St, San Francisco, CA, 94121",
#  'Bin 38, 3232 Scott St, San Francisco, CA, 94123',
#  'Bin 55, 780 Mission St, San Francisco, CA, 94103',
#  'Bisou, 2367 Market St, San Francisco, CA, 94114',
#  'Bistro 10UN, 1130 Market St, San Francisco, CA, 94102',
#  'Bistro Aix, 3340 Steiner St, San Francisco, CA, 94123',
#  'Bistro Boudin, 160 Jefferson St, San Francisco, CA, 94133',
#  'Bistro Burger, 201 Mission St, San Francisco, CA, 94105',
#  'Bistro Burger, 333 Bush St, San Francisco, CA, 94104',
#  'Bistro Burger, 343 Sansome St, San Francisco, CA, 94104',
#  'Bistro Burger, 845 Market St, San Francisco, CA, 94103',
#  'Bistro Central Parc, 560 Central Ave, San Francisco, CA, 94117',
#  'Bistro Gambrinus, 1813 Fulton St, San Francisco, CA, 94117',
#  "Bistro L'Aviateur, 2850 21st St, San Francisco, CA, 94110",
#  'Bistro SF Grill, 2819 California St, San Francisco, CA, 94115',
#  'Blackpoint Cafe, 882 North Point St, San Francisco, CA, 94109',
#  'Blu Restaurant and Cafe, 747 Market St, San Francisco, CA, 94103',
#  'Blue Front Cafe, 1430 Haight St, San Francisco, CA, 94117',
#  'Blueprint Tap Room, 680 8th St, San Francisco, CA, 94103',
#  'Blush Wine Bar, 476 Castro St, San Francisco, CA, 94114',
#  'Boccalone, Ferry Plaza, San Francisco, CA, 94111',
#  'Bonanza Restaurant, 16 Toland St, San Francisco, CA, 94124',
#  'Boogaloos, 3296 22nd St, San Francisco, CA, 94110',
#  'Boston Market, 2300 16th St, San Francisco, CA, 94103',
#  'Bouche, 603 Bush St, San Francisco, CA, 94108',
#  'Boudin Bakery, 25 Van Ness Ave, San Francisco, CA, 94102',
#  'Boudin Bakery, Pier 39, Space 5-Q, San Francisco, CA, 94133',
#  'Boudin Sourdough Bakery & Cafe, 160 Jefferson St, San Francisco, CA, 94133',
#  'Boudin Sourdough Bakery & Cafe, 19th Ave & Winston St, San Francisco, CA, 94103',
#  'Boudin Sourdough Bakery & Cafe, 399 10th Ave, San Francisco, CA, 94118',
#  'Boudin Sourdough Bakery & Cafe, 4 Embarcadero Ctr, San Francisco, CA, 94111',
#  'Boulevard, 1 Mission St, San Francisco, CA, 94105',
#  'Brannan Street Cafe, 274 Brannan St, San Francisco, CA, 94107',
#  'Brasserie S&P, 222 Sansome St, San Francisco, CA, 94104',
#  'Bravo Pizza, 5145 Mission St, San Francisco, CA, 94112',
#  "Brenda's French Soul Food, 652 Polk St, San Francisco, CA, 94102",
#  'Broadway Dim Sum, 684 Broadway, San Francisco, CA, 94133',
#  'Broadway Pizza, 448 Broadway, San Francisco, CA, 94133',
#  'Broken Record, 1166 Geneva Ave, San Francisco, CA, 94112',
#  "Bruno's, 2389 Mission St, San Francisco, CA, 94110",
#  'Buckhorn Grill, 101 4th St, San Francisco, CA, 94103',
#  'Buckhorn Grill, 4 Embarcadero Ctr, San Francisco, CA, 94111',
#  'Buckhorn Grill, 4 Perry St, San Francisco, CA, 94107',
#  'Buckhorn Grill, 865 Market St, San Francisco, CA, 94103',
#  'Buffalo Burgers, 5317 Geary Blvd, San Francisco, CA, 94121',
#  'Bullshead, 840 Ulloa St, San Francisco, CA, 94127',
#  'Burger Bar, 251 Geary St, San Francisco, CA, 94102',
#  'Burger Gourmet, 101 Spear St, San Francisco, CA, 94105',
#  'Burger House, 237 Powell St, San Francisco, CA, 94102',
#  'Burger Joint, 807 Valencia St, San Francisco, CA, 94110',
#  'Burger King, 1298 Howard St, San Francisco, CA, 94103',
#  'Burger King, 1690 Valencia St, San Francisco, CA, 94110',
#  'Burger King, 1701 Fillmore St, San Francisco, CA, 94115',
#  'Burger King, 245 Bay Shore Blvd, San Francisco, CA, 94124',
#  'Burger King, 25 Van Ness Ave, San Francisco, CA, 94102',
#  'Burger King, 2739 Taylor St, San Francisco, CA, 94133',
#  'Burger King, 2978 16th St, San Francisco, CA, 94103',
#  'Burger King, 35 Powell St, San Francisco, CA, 94102',
#  'Burger King, 360 Bay St, San Francisco, CA, 94133',
#  'Burger King, 3900 Geary Blvd, San Francisco, CA, 94118',
#  'Burger King, 4780 Mission St, San Francisco, CA, 94112',
#  'Burger King, 724 La Playa St, San Francisco, CA, 94121',
#  'Burger King, 819 Van Ness Ave, San Francisco, CA, 94109',
#  'Burger Urge, 1599 Haight St, San Francisco, CA, 94117',
#  'Burgermeister, 138 Church St, San Francisco, CA, 94114',
#  'Burgermeister, 759 Columbus Ave, San Francisco, CA, 94133',
#  'Burgermeister, 86 Carl St, San Francisco, CA, 94117',
#  'CDXX, 5800 3rd Street, San Francisco, CA, 94124',
#  'Cable Car Cafe, 519 Powell St, San Francisco, CA, 94108',
#  'Cable Car City Pub & Cafe, 1 Hallidie Plz, San Francisco, CA, 94102',
#  "Caesar's Cafe & Crepes, 208 Valencia St, San Francisco, CA, 94103",
#  'Cafe Andree, 526 Sutter St, San Francisco, CA, 94102',
#  'Cafe Bello, 2885 Diamond St, San Francisco, CA, 94131',
#  'Cafe Benally, 1131 Taraval St, San Francisco, CA, 94116',
#  'Cafe Bistro (Nordstroms), 865 Market St, San Francisco, CA, 94103',
#  'Cafe Claude, 7 Claude Ln, San Francisco, CA, 94108',
#  'Cafe Claude Marina, 2120 Greenwich St, San Francisco, CA, 94123',
#  'Cafe Du Soleil, 345 3rd St, San Francisco, CA, 94107',
#  'Cafe Encore, 488 Post St, San Francisco, CA, 94102',
#  'Cafe Europa, 4318 California St, San Francisco, CA, 94118',
#  'Cafe Flore, 2298 Market St, San Francisco, CA, 94114',
#  'Cafe Francisco, 2161 Powell St, San Francisco, CA, 94133',
#  'Cafe GoLo, 1602 Lombard St, San Francisco, CA, 94123',
#  'Cafe Jacqueline, 1454 Grant Ave, San Francisco, CA, 94133',
#  'Cafe La Taza, 2475 Mission St, San Francisco, CA, 94110',
#  'Cafe Leah, 25 Beale St, San Francisco, CA, 94105',
#  'Cafe Leah 2, 77 Beale St, San Francisco, CA, 94105',
#  'Cafe Lombard, 1424 Lombard St, San Francisco, CA, 94123',
#  'Cafe Med, 201 Pine St, San Francisco, CA, 94104',
#  'Cafe Meuse, 1400 Pacific Ave, San Francisco, CA, 94109',
#  'Cafe Phoenix, 1234 Indiana St, San Francisco, CA, 94107',
#  'Cafe Playfield, 1 Zoo Rd, San Francisco, CA, 94132',
#  'Cafe Rain Tree, 118 West Portal Ave, San Francisco, CA, 94127',
#  'Cafe Rain Tree, 654 Irving St, San Francisco, CA, 94122',
#  'Cafe Taboo, 600 York St, San Francisco, CA, 94110',
#  'Cafe Zazo, 64 14th St, San Francisco, CA, 94103',
#  'Cafe Zoet, 520 Leavenworth St, San Francisco, CA, 94109',
#  'Cafe at the Opera, 301 Van Ness Avenue, San Francisco, CA, 94102',
#  'Cafe de la Presse, 352 Grant Ave, San Francisco, CA, 94108',
#  'Caffe Museo, 151 3rd St, San Francisco, CA, 94103',
#  'Caffe Union, 1830 Union St, San Francisco, CA, 94123',
#  'Calibur, 68 W Portal Ave, San Francisco, CA, 94127',
#  'California Crisp, 3251 20th Ave, San Francisco, CA, 94132',
#  'Campton Place, 340 Stockton St, San Francisco, CA, 94108',
#  'Careme 350, 350 Rhode Island St, San Francisco, CA, 94103',
#  "Carl's Jr., 1 Hallidie Plz, San Francisco, CA, 94102",
#  "Carl's Jr., 10 United Nations Plz, San Francisco, CA, 94102",
#  "Carl's Jr., 4 Embarcadero Ctr, San Francisco, CA, 94111",
#  'Cassava Bakery & Cafe, 3519 Balboa St, San Francisco, CA, 94121',
#  'Castagna, 2015 Chestnut St, San Francisco, CA, 94123',
#  "Causwell's, 2346 Chestnut St, San Francisco, CA, 94123",
#  'Cefiore, 59 New Montgomery St, San Francisco, CA, 94105',
#  'Central Kitchen, 3000 20th St, San Francisco, CA, 94110',
#  'Chambers Eat & Drink, 601 Eddy St, San Francisco, CA, 94109',
#  'Chapeau!, 126 Clement St, San Francisco, CA, 94118',
#  "Charlie's Deli Cafe, 3202 Folsom St, San Francisco, CA, 94117",
#  'Chaya Brasserie, 132 The Embarcadero, San Francisco, CA, 94105',
#  'Cheese Plus, 2001 Polk St, San Francisco, CA, 94109',
#  'Chestnut Diner, 1312 Chestnut St, San Francisco, CA, 94123',
#  'Chez Julien, 100 Bush St, San Francisco, CA, 94104',
#  'Chez Maman, 1453 18th St, San Francisco, CA, 94107',
#  'Chez Maman, 2223 Union St, San Francisco, CA, 94123',
#  'Chez Maman, 401 Gough St, San Francisco, CA, 94102',
#  'Chez Papa, 4 Mint Plz, San Francisco, CA, 94103',
#  'Chiotras, 858 Rhode Island St, San Francisco, CA, 94107',
#  "Chloe's Cafe, 1399 Church St, San Francisco, CA, 94114",
#  'ChouChou, 400 Dewey Blvd, San Francisco, CA, 94116',
#  "Chouquet's, 2500 Washington St, San Francisco, CA, 94115",
#  'Chow Church, 215 Church St, San Francisco, CA, 94114',
#  'Chowder Hut Fresh Grill, 2890 Taylor St, San Francisco, CA, 94133',
#  'Cigar Bar & Grill, 850 Montgomery St, San Francisco, CA, 94133',
#  "Cindy's Market, 2084 Hayes Street, San Francisco, CA, 94117",
#  'Circa, 2001 Chestnut St, San Francisco, CA, 94123',
#  'Citizens Band, 1198 Folsom St, San Francisco, CA, 94103',
#  'City Club of San Francisco, 155 Sansome St, San Francisco, CA, 94104',
#  'City Gourmet, 590 3rd St, San Francisco, CA, 94107',
#  'Citys Choice, 301 5th St, San Francisco, CA, 94107',
#  "Clancey's Market & Deli, 3960 Irving St, San Francisco, CA, 94122",
#  "Clare's, 3505 17th St, San Francisco, CA, 94110",
#  'Claudine, 8 Claude Ln, San Francisco, CA, 94108',
#  'Clement Street Bar & Grill, 708 Clement St, San Francisco, CA, 94118',
#  'Clock Bar, 335 Powell St, San Francisco, CA, 94102',
#  "Cobb's Comedy Club, 915 Columbus Ave, San Francisco, CA, 94133",
#  'Cockscomb, 564 4th St, San Francisco, CA, 94107',
#  'Cocola Bakery & Pastry, 865 Market St, San Francisco, CA, 94103',
#  'Cocotte, 1521 Hyde St, San Francisco, CA, 94109',
#  'Coi, 373 Broadway, San Francisco, CA, 94133',
#  'Commonwealth, 2224 Mission St, San Francisco, CA, 94110',
#  'Community Table, 3200 California St , San Francisco, CA, 94118',
#  'Concordia Argonaut, 1142 Van Ness Ave, San Francisco, CA, 94109',
#  'Continental Cafe & Deli, 845 Howard St, San Francisco, CA, 94103',
#  'Cool Cravings, 1635 Divisadero St, San Francisco, CA, 94115',
#  'Corner Bakery Cafe, 665 Market St, San Francisco, CA, 94105',
#  'Corsagna Deli, 1668 Union St, San Francisco, CA, 94123',
#  'Couchy Potatoes, 1251 20th Ave, San Francisco, CA, 94122',
#  'Cove Cafe, 434 Castro St, San Francisco, CA, 94114',
#  'Cowgirl Creamery Sidekick, Ferry Plaza, San Francisco, CA, 94102',
#  'Crepe Cone by Sophie, 684 King St, San Francisco, CA, 94107',
#  'Crepe Express, 1476 Haight St, San Francisco, CA, 94117',
#  'Crepe La Vie, 1727 Haight St, San Francisco, CA, 94177',
#  'Crepe Madame, 685 Harrison St, San Francisco, CA, 94107',
#  'Crepe O Chocolat, 75 Ofarrell St, San Francisco, CA, 94108',
#  'Crepe Temptations, 2575 Judah St, San Francisco, CA, 94122',
#  'Crepe and Curry, 5 Embarcadero Ctr, San Francisco, CA, 94111',
#  'Creperie Saint Germain, 222 2nd St, San Francisco, CA, 94105',
#  'Creperie Saint-Germain, 555 California St, San Francisco, CA, 94104',
#  'Crepes A Go Go, 350 11th St, San Francisco, CA, 94103',
#  'Crepes On Cole, 100 Carl St, San Francisco, CA, 94117',
#  'Crepes Ooh La La, 1220 Polk St, San Francisco, CA, 94109',
#  'Crepevine, 216 Church St, San Francisco, CA, 94114',
#  'Crepevine, 624 Irving St, San Francisco, CA, 94122',
#  'Crustacean, 1475 Polk St, San Francisco, CA, 94109',
#  'Curbside Cafe, 2417 California St, San Francisco, CA, 94115',
#  'Custom Burger, 121 7th St, San Francisco, CA, 94102',
#  "Cybelle's Front Room, 1385 9th Ave, San Francisco, CA, 94122",
#  "D'urso Italian Delicatessen, 236 Townsend St, San Francisco, CA, 94107",
#  "Da Kine's Hawaiian Bbq, 4808 Mission St, San Francisco, CA, 94112",
#  "Daddy Boy's Pizza, 4524 3rd St, San Francisco, CA, 94124",
#  'Daily Grill, 347 Geary St, San Francisco, CA, 94102',
#  "David's, 474 Geary St, San Francisco, CA, 94102",
#  'De Young Museum Cafe, 50 Hagiwara Tea Garden Dr, San Francisco, CA, 94118',
#  'Dear Mom (Fogcutter), 2700 16th St, San Francisco, CA, 94103',
#  'Delancey Street, 600 Embarcadero, San Francisco, CA, 94107',
#  'Delessio Market & Bakery, 1695 Market St, San Francisco, CA, 94103',
#  'Deli & ..., 124 Montgomery St, San Francisco, CA, 94104',
#  'Delica, 1 Ferry Plaza, San Francisco, CA, 94111',
#  'Delicioso Creperie, 2948 Folsom St, San Francisco, CA, 94110',
#  'Delish Deli, 752 Van Ness Ave, San Francisco, CA, 94102',
#  "Denny's, 1700 Post St, San Francisco, CA, 94115",
#  "Denny's, 495 Beach St, San Francisco, CA, 94133",
#  "Denny's, 816 Mission St, San Francisco, CA, 94103",
#  'Diala Pizza 2, 2424 Mission St, San Francisco, CA, 94110',
#  'Diamond Cafe, 751 Diamond St, San Francisco, CA, 94114',
#  "Diller's, 348 Pine St, San Francisco, CA, 94104",
#  'Dirty Habit, 12 4th St, San Francisco, CA, 94103',
#  'Dobbs Ferry, 409 Gough St, San Francisco, CA, 94102',
#  "Doc's Of The Bay, Location Varies, San Francisco, CA, 94123",
#  "Domino's Pizza, 1408 Fillmore St, San Francisco, CA, 94115",
#  "Domino's Pizza, 3116 Noriega St, San Francisco, CA, 94122",
#  "Domino's Pizza, 320 Bay Shore Blvd, San Francisco, CA, 94124",
#  "Domino's Pizza, 5200 Geary Blvd, San Francisco, CA, 94118",
#  "Domino's Pizza, 876 Geary St, San Francisco, CA, 94109",
#  'Double Decker, 465 Grove St, San Francisco, CA, 94102',
#  'Double Play, 2401 16th St, San Francisco, CA, 94103',
#  'Dr. Teeth and the Electric Mayhem, 2323 Mission St, San Francisco, CA, 94110',
#  'Drake, 508 4th St, San Francisco, CA, 94107',
#  'Drumm Liquor & Deli, 15 Drumm St, San Francisco, CA, 94111',
#  'Dusty Buns, Location Varies, San Francisco, CA, 94103',
#  'Dux, 780 Valencia St, San Francisco, CA, 94110',
#  'Eagle Cafe, Pier 39, San Francisco, CA, 94133',
#  'Eat Curbside, 500 Mission St, San Francisco, CA, 94105',
#  'Ebb Tide Cafe, 1500 S Van Ness Ave, San Francisco, CA, 94110',
#  'Eclipse Cafe, 5 Embarcadero Ctr, San Francisco, CA, 94111',
#  'Eden Lounge, 1692 Stockton St, San Francisco, CA, 94133',
#  'Educated Palate, 88 4th St, San Francisco, CA, 94103',
#  'Eleven O One, 1101 Polk St, San Francisco, CA, 94109',
#  "Emo's Cafe, 201 Turk St, San Francisco, CA, 94102",
#  'Eureka, 4063 18th St, San Francisco, CA, 94114',
#  'EuroBistro, Location Varies, San Francisco, CA, 94103',
#  "Eva's Hawaiian Cafe, 731 Clement St, San Francisco, CA, 94118",
#  'Fable, 558 Castro St, San Francisco, CA, 94114',
#  'Farm:Table, 754 Post St, San Francisco, CA, 94109',
#  'Fat Beli Deli, 2598 San Bruno Ave, San Francisco, CA, 94134',
#  'Fat Slice, 1535 Haight St, San Francisco, CA, 94117',
#  'Fatt Dog, 200 Pine St, San Francisco, CA, 94104',
#  'Feed, 215 Fremont, San Francisco, CA, 94105',
#  'Fins On the Hoof, Location Varies, San Francisco, CA, 94103',
#  'Fireburger, 2138 Irving St, San Francisco, CA, 94122',
#  'Firefly, 4288 24th St, San Francisco, CA, 94114',
#  'Firewood Cafe, 4248 18th St, San Francisco, CA, 94114',
#  'First Crush, 101 Cyril Magnin St, San Francisco, CA, 94102',
#  'Fish & Farm, 339 Taylor St, San Francisco, CA, 94102',
#  "Fisherman's Pizzeria, 2800 Leavenworth St, San Francisco, CA, 94133",
#  "Fishermen's Grotto #9, 2847 Taylor St, San Francisco, CA, 94133",
#  'FiveTen Burger, location varies, San Francisco, CA, 94103',
#  'Fleur De Sel, 308 Kearny St, San Francisco, CA, 94108',
#  "Flipper's, 482 Hayes St, San Francisco, CA, 94102",
#  'Flour + Water, 2401 Harrison St, San Francisco, CA, 94110',
#  'Fly Bar And Restaurant, 1085 Sutter St, San Francisco, CA, 94109',
#  'Fog City, 1300 Battery St, San Francisco, CA, 94111',
#  'Forbes Island, Pier 39, San Francisco, CA, 94133',
#  'Fort Mason Market & Deli, 1701 Greenwich St, San Francisco, CA, 94123',
#  'Foundation Cafe, 335 Kearny St, San Francisco, CA, 94108',
#  'Fountain Cafe, 50 Post St, San Francisco, CA, 94104',
#  'Fox Plaza Deli Cafe, 1390 Market St, San Francisco, CA, 94102',
#  'France Delices, Location Varies, San Francisco, CA, 94123',
#  'Frances, 3870 17th St, San Francisco, CA, 94114',
#  'Freddies Sandwiches #2, 1488 Pine St, San Francisco, CA, 94109',
#  'French Creme Brulee, 720 Market St, San Francisco, CA, 94108',
#  'Fresco Pizza & Shawarma, 1338 Polk St, San Francisco, CA, 94109',
#  'Fringale, 570 4th St, San Francisco, CA, 94107',
#  'Frisco Fried, 5176 3rd St, San Francisco, CA, 94124',
#  'Frjtz, 579 Hayes St, San Francisco, CA, 94102',
#  'Frjtz, 590 Valencia St, San Francisco, CA, 94110',
#  'Front Door Cafe, 1 Front St, San Francisco, CA, 94111',
#  'G Food Lounge, Location Varies, San Francisco, CA, 94107',
#  'GS Riverside BBQ, 3751 Geary Blvd, San Francisco, CA, 94118',
#  'Galette 88, 88 Hardie Pl, San Francisco, CA, 94104',
#  'Gallery Cafe, 1200 Mason St, San Francisco, CA, 94108',
#  "Gambino's, One Market Plz, San Francisco, CA, 94105",
#  'Gamine, 2223 Union St, San Francisco, CA, 94123',
#  "Ganim's Deli, 1135 18th St, San Francisco, CA, 94107",
#  'Garcon, 1101 Valencia St, San Francisco, CA, 94110',
#  "Garibaldi's, 347 Presidio Ave, San Francisco, CA, 94115",
#  'Gaspar Brasserie, 185 Sutter St, San Francisco, CA, 94104',
#  'Geneva Steak House, 5130 Mission St, San Francisco, CA, 94112',
#  'Genki Crepes, 330 Clement St, San Francisco, CA, 94118',
#  "George's Zoo, 2560 Sloat Blvd, San Francisco, CA, 94116",
#  'Geppetto, 658 Vallejo St, San Francisco, CA, 94133',
#  'Gestalt Haus, 3159 16th St, San Francisco, CA, 94103',
#  'Globe, 290 Pacific Ave, San Francisco, CA, 94111',
#  "Go Getter's Deli, 100 Gough Street, San Francisco, CA, 94102",
#  'Go Streatery, Location Varies, San Francisco, CA, 94102',
#  'Gold Coast Grill & Catering, 1650 Holloway Ave, San Francisco, CA, 94132',
#  'Golden Gate Indian Cuisine & Pizza, 1388 46th Ave, San Francisco, CA, 94122',
#  'Golden Gate Meat Company, 1 Ferry Building, San Francisco, CA, 94111',
#  'Good Eats Cafe, 200 Pine St, San Francisco, CA, 94104',
#  "Gott's Roadside Tray Gourmet, 1 Ferry Building, San Francisco, CA, 94111",
#  'Grand Seven Food Liquer & Deli, 1740 Cesar Chavez St, San Francisco, CA, 94124',
#  'Green Heart Foods, 3321 20th St, San Francisco, CA, 94110',
#  'Griddle Fresh, 4007 24th St, San Francisco, CA, 94114',
#  'Grub, 758 Valencia St, San Francisco, CA, 94110',
#  'Grubstake, 1525 Pine St, San Francisco, CA, 94109',
#  "Grumpy's American Pub, 125 Vallejo St, San Francisco, CA, 94111",
#  "Guerra's Deli & Meats, 490 Taraval St, San Francisco, CA, 94116",
#  'H20 Cafe, 1330 Polk St, San Francisco, CA, 94109',
#  'Haagen Dazs, 3251 20th Ave, San Francisco, CA, 94132',
#  'Hamburger Haven, 800 Clement St, San Francisco, CA, 94118',
#  'Handy Delicatessen, 1815 Irving St, San Francisco, CA, 94122',
#  "Harris', 2100 Van Ness Ave, San Francisco, CA, 94109",
#  'Harrow, 357 Kearny St, San Francisco, CA, 94108',
#  "Harry Denton's Starlight Room, 450 Powell St, San Francisco, CA, 94102",
#  "Harry's Bar, 2020 Fillmore St, San Francisco, CA, 94115",
#  'Harvest Urban Market, 191 8th St, San Francisco, CA, 94103',
#  "Harvey's, 500 Castro St, San Francisco, CA, 94114",
#  'Hawaii West Bbq, 729 Vallejo St, San Francisco, CA, 94133',
#  'Hawaiian Drive Inn, 2600 San Bruno Ave, San Francisco, CA, 94134',
#  'Hawaiian Drive Inn. #28, 4827 Mission St, San Francisco, CA, 94112',
#  "Hazel's Kitchen, 1331 18th St, San Francisco, CA, 94107",
#  'Heirloom Cafe, 2500 Folsom St, San Francisco, CA, 94110',
#  'Hella Vegan Eats, Location Varies, San Francisco, CA, 94110',
#  'Herbivore, 531 Divisadero St, San Francisco, CA, 94117',
#  'Heyday, 180 Spear St, San Francisco, CA, 94105',
#  'Hi Dive, Pier 28 1/2, San Francisco, CA, 94105',
#  'Hi Tops, 2247 Market St, San Francisco, CA, 94114',
#  'Hillside Supper Club, 300 Precita Ave, San Francisco, CA, 94110',
#  'Hillstone, 1800 Montgomery St, San Francisco, CA, 94111',
#  "Hoffman's, 1000 Guerrero St, San Francisco, CA, 94110",
#  'Hog & Rocks, 3431 19th St, San Francisco, CA, 94110',
#  'Hole in the Wall Pizza, 3244 Scott St, San Francisco, CA, 94123',
#  'Holey Bagel, 3872 24th St, San Francisco, CA, 94114',
#  'Hollow Cow Market, 3165 Steiner St, San Francisco, CA, 94123',
#  'Holy Grill, 659 Townsend St, San Francisco, CA, 94103',
#  'Home Plate, 2274 Lombard St, San Francisco, CA, 94123',
#  'Home Skillet, 1001 Market St, San Francisco, CA, 94103',
#  'Honey Honey Cafe & Crepery, 599 Post St, San Francisco, CA, 94102',
#  'Hopwater Distribution, 850 Bush St, San Francisco, CA, 94108',
#  'Horatius, 350 Kansas St, San Francisco, CA, 94103',
#  'Horizon Restaurant & Lounge, 498 Broadway St, San Francisco, CA, 94133',
#  "Horner's Corner, 1199 Church St, San Francisco, CA, 94114",
#  'House of Bagels, 5030 Geary Blvd, San Francisco, CA, 94118',
#  "Howard's Cafe, 1309 9th Ave, San Francisco, CA, 94122",
#  'Huxley, 846 Geary St, San Francisco, CA, 94109',
#  'IHOP, 200 Beach St, San Francisco, CA, 94133',
#  'In-N-Out Burger, 333 Jefferson St, San Francisco, CA, 94133',
#  'In-N-Out Burger, 333 Jefferson St, San Francisco, CA, 94133',
#  'Indigo, 687 McAllister St, San Francisco, CA, 94102',
#  'Ironside, 680A 2nd St, San Francisco, CA, 94107',
#  'Irving Street Cafe, 716 Irving St, San Francisco, CA, 94122',
#  'Isa, 3324 Steiner St, San Francisco, CA, 94123',
#  "Israel's Strictly Kosher, 675 Victoria St, San Francisco, CA, 94127",
#  "It's A Grind Coffee House, 1800 Polk St, San Francisco, CA, 94109",
#  "It's Top's Coffee Shop, 1801 Market St, San Francisco, CA, 94103",
#  'J & V Restaurant and Catering, 2095 Jerrold Ave, San Francisco, CA, 94124',
#  'J Shack, Location Varies, San Francisco, CA, 94103',
#  'J Tu Cafe, 582 Sutter St, San Francisco, CA, 94102',
#  "JB's Place, 1435 17th St, San Francisco, CA, 94107",
#  "Jablow's Meats, 86 2nd St, San Francisco, CA, 94105",
#  'Jack in the Box, 366 Bay Shore Blvd , San Francisco, CA, 94124',
#  'Jack in the Box, 400 Geary St, San Francisco, CA, 94102',
#  'Jack in the Box, 42 1st St, San Francisco, CA, 94105',
#  'Jack in the Box, 4649 Geary Blvd, San Francisco, CA, 94118',
#  'Jack in the Box, 808 Mission St, San Francisco, CA, 94103',
#  'Jacks Cannery Bar, 2801 Leavenworth St, San Francisco, CA, 94133',
#  "Jake's Place, 293 Bayshore Blvd, San Francisco, CA, 94124",
#  'Jamba Juice, 1200 Van Ness Ave, San Francisco, CA, 94109',
#  'Jamba Juice, 2130 Fulton St, San Francisco, CA, 94117',
#  'Jamba Juice, 250 Montgomery St, San Francisco, CA, 94104',
#  'Jamba Juice, 3480 California St, San Francisco, CA, 94118',
#  'Jamba Juice, 70 Mission St, San Francisco, CA, 94105',
#  'Jamber, 858 Folsom St, San Francisco, CA, 94107',
#  'Jardiniere, 300 Grove St, San Francisco, CA, 94102',
#  "Jasmin's Cafe & Deli, 809 Bush St, San Francisco, CA, 94108",
#  "Jasper's Corner Tap & Kitchen, 401 Taylor St, San Francisco, CA, 94102",
#  'Java House, Pier 40, San Francisco, CA, 94107',
#  "Jillian's, 101 4th St, San Francisco, CA, 94103",
#  "Joanie's Happy Days Diner, 1329 Columbus Ave, San Francisco, CA, 94133",
#  "John's Burgers, 1114 Market St, San Francisco, CA, 94102",
#  "John's Grill, 63 Ellis St, San Francisco, CA, 94102",
#  'Johnny Rockets, 81 Jefferson St, San Francisco, CA, 94133',
#  "Johnson's Bar-b-que, 2648 San Bruno Ave, San Francisco, CA, 94134",
#  'Jones, 620 Jones St, San Francisco, CA, 94102',
#  "Judy's Cafe, 2268 Chestnut St, San Francisco, CA, 94123",
#  "Juicey Lucy's, 703 Columbus Ave, San Francisco, CA, 94133",
#  "Juicy Lucy's, 703 Columbus Ave, San Francisco, CA, 94133",
#  'Jump Start Coffee & Grocery, 1192 Guerrero St, San Francisco, CA, 94110',
#  'KFC - Kentucky Fried Chicken, 1150 Taraval St, San Francisco, CA, 94116',
#  'KFC - Kentucky Fried Chicken, 1610 Jerrold Ave, San Francisco, CA, 94124',
#  'KFC - Kentucky Fried Chicken, 1881 Geary Blvd, San Francisco, CA, 94115',
#  'KFC - Kentucky Fried Chicken, 1900 Irving St, San Francisco, CA, 94122',
#  'KFC - Kentucky Fried Chicken, 200 Duboce Ave, San Francisco, CA, 94103',
#  'KFC - Kentucky Fried Chicken, 2040 Ocean Ave, San Francisco, CA, 94127',
#  'KFC - Kentucky Fried Chicken, 2101 Lombard St, San Francisco, CA, 94123',
#  'KFC - Kentucky Fried Chicken, 4150 Geary Blvd, San Francisco, CA, 94118',
#  'KFC - Kentucky Fried Chicken, 4285 Mission St, San Francisco, CA, 94112',
#  'KFC - Kentucky Fried Chicken, 691 Eddy St, San Francisco, CA, 94109',
#  "Kate O'Briens, 579 Howard St, San Francisco, CA, 94105",
#  "Kate's Kitchen, 471 Haight St, San Francisco, CA, 94117",
#  'Keiko a Nob Hill, 1250 Jones St, San Francisco, CA, 94109',
#  "Kenny's Chinese & American, 518 S Van Ness Ave, San Francisco, CA, 94110",
#  'Kezar Bar & Restaurant, 900 Cole St, San Francisco, CA, 94117',
#  'Kinfolk, 903 Cortland Ave, San Francisco, CA, 94110',
#  'King Salame Sandwich Shop, 1926 Lombard Street, San Francisco, CA, 94123',
#  'King of Currywurst, 425 Divisadero St, San Francisco, CA, 94117',
#  'Kitchen Story, 3499 16th St, San Francisco, CA, 94114',
#  'Knuckles Sports Bar & Grill, 555 N Point St, San Francisco, CA, 94133',
#  'L & L Hawaiian BBQ, 312 Kearny St, San Francisco, CA, 94108',
#  "L'Olivier, 465 Davis Ct, San Francisco, CA, 94111",
#  "L'ardoise, 151 Noe St, San Francisco, CA, 94114",
#  'La Bergerie, 4221 Geary Blvd, San Francisco, CA, 94118',
#  'La Boulange, 1266 9th Ave, San Francisco, CA, 94122',
#  'La Boulange, 1909 Union St, San Francisco, CA, 94123',
#  'La Boulange, 2043 Fillmore St, San Francisco, CA, 94115',
#  'La Boulange, 222 Sutter St, San Francisco, CA, 94115',
#  'La Boulange, 3898 24th St, San Francisco, CA, 94114',
#  'La Boulange, 465 California St, San Francisco, CA, 94104',
#  'La Boulange de Columbus, 543 Columbus St, San Francisco, CA, 94133',
#  'La Boulange de Hayes, 500 Hayes St, San Francisco, CA, 94102',
#  'La Boulange de Market, 685 Market St, San Francisco, CA, 94103',
#  'La Boulange du Dome, 845 Market St, San Francisco, CA, 94103',
#  'La Ciudad De Mexico, 200 6th Ave, San Francisco, CA, 94118',
#  'La Folie, 2316 Polk St, San Francisco, CA, 94109',
#  'La Galleria Cafe, 930 Bush St, San Francisco, CA, 94109',
#  'LaLe, 731 Irving St, San Francisco, CA, 94122',
#  'Lafayette Coffee Shop, 611 Larkin St, San Francisco, CA, 94109',
#  'Lagos Pizza, 448 Broadway, San Francisco, CA, 94133',
#  'Lakeside Cafe, 2529 Ocean Ave, San Francisco, CA, 94132',
#  'Larkin Express, 452 Larkin St, San Francisco, CA, 94102',
#  "Larry Flynt's Hustler Club, 1031 Kearny St, San Francisco, CA, 94133",
#  'Last Drop Tavern, 550 Powell St, San Francisco, CA, 94108',
#  'Laszlo Bar, 2526 Mission St, San Francisco, CA, 94110',
#  'Lazy Bear, 3416 19th St, San Francisco, CA, 94110',
#  'Le Central Bistro, 453 Bush St, San Francisco, CA, 94108',
#  'Le Charm, 315 5th St, San Francisco, CA, 94107',
#  'Le Marais Bakery, 2066 Chestnut St, San Francisco, CA, 94123',
#  "Le Petitt's Kitchen, 265 Golden Gate Ave, San Francisco, CA, 94102",
#  'Le Regency, 18 California St, San Francisco, CA, 94111',
#  'Le Zinc, 4063 24th St, San Francisco, CA, 94114',
#  'LeBeau Nob Hill Market, 1263 Leavenworth St, San Francisco, CA, 94109',
#  'Leaping Lemur Cafe, 1 Zoo Rd, San Francisco, CA, 94132',
#  "Lee's, 550 California St, San Francisco, CA, 94104",
#  "Lee's Deli, 117 New Montgomery St, San Francisco, CA, 94105",
#  "Lee's Deli, 222 Front St, San Francisco, CA, 94111",
#  "Lee's Deli, 280 Battery St, San Francisco, CA, 94111",
#  "Lee's Deli, 303 2nd St, San Francisco, CA, 94107",
#  "Lee's Deli, 615 Market St, San Francisco, CA, 94104",
#  "Lefty O'Doul's, 333 Geary St, San Francisco, CA, 94102",
#  'Legion Of Honor Cafe, 100 34th Ave, San Francisco, CA, 94121',
#  'Leland Tea Company, 1416 Bush St, San Francisco, CA, 94109',
#  "Leopold's, 2400 Polk St, San Francisco, CA, 94109",
#  'Les Clos, 234 Townsend St, San Francisco, CA, 94107',
#  'Les Joulins Jazz Bistro, 44 Ellis St, San Francisco, CA, 94102',
#  'Level III, 500 Post St, San Francisco, CA, 94102',
#  'Levi Plaza Cafe, 1155 Battery St, San Francisco, CA, 94111',
#  'Library Bar, 562 Sutter St, San Francisco, CA, 94102',
#  "Lilah Belle's, 1207 Divisadero, San Francisco, CA, 94115",
#  "Lilly's Bar-B-Que, 705 Divisadero St, San Francisco, CA, 94117",
#  'Little Cafe , 955 Market Street, San Francisco, CA, 94103',
#  'Little Griddle, 1400 Market St, San Francisco, CA, 94102',
#  'Little Heaven Deli, 2348 Mission St, San Francisco, CA, 94110',
#  "Little Joe's Pizzeria, 5006 Mission St, San Francisco, CA, 94112",
#  'Little Piglet Cafe, 451 9th St, San Francisco, CA, 94103',
#  'Little Red Riding Truck, Location Varies, San Francisco, CA, 94103',
#  'Little Wok, 2675 Ocean Ave, San Francisco, CA, 94132',
#  'Local, 330 1st St, San Francisco, CA, 94105',
#  "Lori's Diner, 336 Mason St, San Francisco, CA, 94102",
#  "Lori's Diner, 500 Sutter St, San Francisco, CA, 94102",
#  "Lou's Cafe, 5017 Geary Blvd, San Francisco, CA, 94118",
#  "Louie's Bar & Grill, 55 Stevenson St, San Francisco, CA, 94105",
#  "Louis' Restaurant, 902 Point Lobos Ave, San Francisco, CA, 94121",
#  'Louisiana Famous Fried Chicken, 1325 Fillmore St, San Francisco, CA, 94115',
#  'Louisiana Famous Fried Chicken, 6 6th St, San Francisco, CA, 94103',
#  'LuLu, 816 Folsom St, San Francisco, CA, 94107',
#  'Lucca Delicatessen, 2120 Chestnut St, San Francisco, CA, 94123',
#  'Lucca Food Store, 1899 Irving St, San Francisco, CA, 94122',
#  'Luce, 888 Howard St, San Francisco, CA, 94103',
#  'Lucky Strike Lanes, 200 King St, San Francisco, CA, 94107',
#  'Luna Park, 694 Valencia St, San Francisco, CA, 94110',
#  'Luques, 433 Powell St, San Francisco, CA, 94102',
#  'MKT, 757 Market St, San Francisco, CA, 94103',
#  'MaSo, 50 3rd St, San Francisco, CA, 94103',
#  "Mabel's Just For You Cafe, 732 22nd St, San Francisco, CA, 94107",
#  'Machine Coffee & Deli, 1024 Market St, San Francisco, CA, 94103',
#  'Magnolia, 1398 Haight St, San Francisco, CA, 94117',
#  'Mahalo!, 1376 9th Ave, San Francisco, CA, 94122',
#  'Mama Cass, Location Varies, San Francisco, CA, 94158',
#  "Mama's, 1701 Stockton St, San Francisco, CA, 94133",
#  'Manhattan Hub, 343 Sansome St, San Francisco, CA, 94111',
#  'Marble Slab Creamery, 219 King St, San Francisco, CA, 94107',
#  'Marengo, 1980 Union St, San Francisco, CA, 94123',
#  'Marina Deli, 2299 Chestnut St, San Francisco, CA, 94123',
#  'Marina Submarine, 2299 Union St, San Francisco, CA, 94123',
#  'Marius Deli & Cafe, 150 Toland St, San Francisco, CA, 94124',
#  'Market Mayflower & Deli, 985 Bush St, San Francisco, CA, 94109',
#  'Market Street Grill, 1231 Market St, San Francisco, CA, 94103',
#  'Marla Bakery, 3619 Balboa St, San Francisco, CA, 94121',
#  'Marlowe, 500 Brannan St, San Francisco, CA, 94107',
#  'Mars Bar & Restaurant, 798 Brannan St, San Francisco, CA, 94103',
#  'Martin Macks, 1568 Haight St, San Francisco, CA, 94117',
#  "Martita's Kitchen, 2560 Marin St, San Francisco, CA, 94124",
#  'Mason Pacific, 1358 Mason St, San Francisco, CA, 94133',
#  'Maven, 598 Haight St, San Francisco, CA, 94117',
#  "Max's Market, 555 California St, San Francisco, CA, 94104",
#  "Max's Opera Cafe, 601 Van Ness Ave, San Francisco, CA, 94102",
#  'Mayes Oyster House, 1233 Polk St, San Francisco, CA, 94109',
#  "McCormick & Kuleto's, 900 N Point St, San Francisco, CA, 94109",
#  "McDonald's, 1100 Fillmore St, San Francisco, CA, 94115",
#  "McDonald's, 1201 Ocean Ave, San Francisco, CA, 94112",
#  "McDonald's, 145 Jefferson St, San Francisco, CA, 94133",
#  "McDonald's, 1455 Market St, San Francisco, CA, 94103",
#  "McDonald's, 2011 Mission St, San Francisco, CA, 94110",
#  "McDonald's, 235 Front St, San Francisco, CA, 94111",
#  "McDonald's, 255 Winston Dr, San Francisco, CA, 94132",
#  "McDonald's, 2801 Mission St, San Francisco, CA, 94110",
#  "McDonald's, 302 Potrero Ave, San Francisco, CA, 94103",
#  "McDonald's, 345 Bay Shore Blvd, San Francisco, CA, 94124",
#  "McDonald's, 441 Pine St, San Francisco, CA, 94104",
#  "McDonald's, 5411 3rd St, San Francisco, CA, 94124",
#  "McDonald's, 5454 Mission St, San Francisco, CA, 94112",
#  "McDonald's, 575 Market St, San Francisco, CA, 94105",
#  "McDonald's, 600 Van Ness Ave, San Francisco, CA, 94102",
#  "McDonald's, 609 Market St, San Francisco, CA, 94105",
#  "McDonald's, 730 Stanyan St, San Francisco, CA, 94117",
#  "McDonald's, 820 Bryant St, San Francisco, CA, 94103",
#  'Me So Hungry, Location Varies, San Francisco, CA, 94103',
#  'Metro Burger Caffe, 247 Fillmore St, San Francisco, CA, 94117',
#  'Michael Mina, 252 California St, San Francisco, CA, 94111',
#  'Michaelis Food Store, 901 N Point St, San Francisco, CA, 94109',
#  "Miller's East Coast Deli, 1725 Polk St, San Francisco, CA, 94109",
#  'Mission Beach Cafe, 198 Guerrero St, San Francisco, CA, 94103',
#  'Mission Grille, 780 Mission St, San Francisco, CA, 94103',
#  'Mission Rock Resort, 817 Terry Francois Blvd, San Francisco, CA, 94158',
#  "Mission's Kitchen, 2738 Mission St, San Francisco, CA, 94110",
#  "Mo's, 1322 Grant Ave, San Francisco, CA, 94133",
#  "MoMo's, 760 2nd St, San Francisco, CA, 94107",
#  "Monk's Kettle, 3141 16th St, San Francisco, CA, 94110",
#  'Monroe, 473 Broadway, San Francisco, CA, 94133',
#  'Monsieur Benjamin, 451 Gough St, San Francisco, CA, 94102',
#  'Monterey Deli, 499 Monterey Blvd, San Francisco, CA, 94127',
#  'Moolicious, 1 Sansome St, San Francisco, CA, 94105',
#  'Moolicious, 135 4th St, San Francisco, CA, 94103',
#  'Morning Due Cafe, 3698 17th St, San Francisco, CA, 94114',
#  "Morty's Delicatessen, 280 Golden Gate Ave, San Francisco, CA, 94102",
#  'Moscone Pizzadeli, 257 3rd St, San Francisco, CA, 94103',
#  "Moscone's At Saint Francis Place, 689 Folsom St, San Francisco, CA, 94107",
#  'Moscow & Tbilisi Bakery Store, 5540 Geary Blvd, San Francisco, CA, 94121',
#  'Mozzarella Di Bufala, 1529 Fillmore St, San Francisco, CA, 94115',
#  'MrCrave, 655 Ellis Street , San Francisco, CA, 94109',
#  'Muka, 370 Grove St, San Francisco, CA, 94102',
#  "Mum's, 1800 Sutter St, San Francisco, CA, 94115",
#  'Municher, Location Varies, San Francisco, CA, 94124',
#  "Murphy's Deli, 560 Mission St, San Francisco, CA, 94105",
#  'My Corner Cafe, 1500 S Van Ness Ave, San Francisco, CA, 94110',
#  'Mymy Coffee Shop, 1500 California St, San Francisco, CA, 94109',
#  'NY Buffalo Wings, 659 Valencia St, San Francisco, CA, 94110',
#  'New Aux Delices, 1002 Potrero Ave, San Francisco, CA, 94110',
#  'New Village Cafe, 1426 Polk St, San Francisco, CA, 94109',
#  "Nickie's, 466 Haight St, San Francisco, CA, 94117",
#  'Nico, 3228 Sacramento St, San Francisco, CA, 94115',
#  'Nob Hill Club, 1 Nob Hill, San Francisco, CA, 94108',
#  'Nob Hill Grille, 969 Hyde St, San Francisco, CA, 94109',
#  'Noeteca, 1551 Dolores St, San Francisco, CA, 94110',
#  'Noir, 581 Hayes St, San Francisco, CA, 94102',
#  'North Beach, 4787 Mission St, San Francisco, CA, 94112',
#  'North Beach Lobster Shack, 532 Green St, San Francisco, CA, 94133',
#  'Nova, 555 2nd St, San Francisco, CA, 94107',
#  'O Izakaya Lounge, 1625 Post St, San Francisco, CA, 94115',
#  'OZ Lounge, 260 Kearny St, San Francisco, CA, 94108',
#  'Old Ship Saloon, 298 Pacific Ave, San Francisco, CA, 94111',
#  'Old Skool Cafe, 1429 Mendell Street, San Francisco, CA, 94124',
#  'Olive, 743 Larkin St, San Francisco, CA, 94109',
#  "Olivia's Fish - Chicken & Gumbo, 4712 3rd St, San Francisco, CA, 94124",
#  'Olympic Flame Cafe, 555 Geary St, San Francisco, CA, 94102',
#  'One Market, 1 Market St, San Francisco, CA, 94105',
#  'One Up, 345 Stockton St, San Francisco, CA, 94108',
#  'Oola, 860 Folsom St, San Francisco, CA, 94107',
#  'Opaque, 689 McAllister St, San Francisco, CA, 94102',
#  'Original Buffalo Wings, 2499 Lombard St, San Francisco, CA, 94123',
#  'Original Ghirardelli Ice Cream & Chocolate Shop, 900 N Point St, San Francisco, CA, 94109',
#  "Orphan Andy's, 3991 17th St, San Francisco, CA, 94114",
#  'Our Court Cafe, 952 Clement St, San Francisco, CA, 94118',
#  "Pal's Takeaway, 3066 24th St, San Francisco, CA, 94110",
#  'Palm Tree Cafe, 1785 Divisadero St, San Francisco, CA, 94115',
#  "Palmer's Tavern, 2298 Fillmore St, San Francisco, CA, 94115",
#  'Panera Bread, 2675 Geary Blvd, San Francisco, CA, 94118',
#  'Panera Bread, 301 King Street, San Francisco, CA, 94158',
#  "Papa John's Pizza, 69 Cambon Dr, San Francisco, CA, 94132",
#  'Paragon, 701 2nd St, San Francisco, CA, 94107',
#  'Parallel 37, 600 Stockton St, San Francisco, CA, 94108',
#  'Paris Pizza and Grill, 448 Broadway, San Francisco, CA, 94133',
#  'Park Chalet, 1000 Great Hwy, San Francisco, CA, 94121',
#  'Park Chow, 1240 9th Ave, San Francisco, CA, 94122',
#  'Park Grill, 333 Battery St, San Francisco, CA, 94111',
#  'Park Tavern, 1652 Stockton St, San Francisco, CA, 94133',
#  'Parkside Tavern, 1940 Taraval St, San Francisco, CA, 94116',
#  "Pat's Cafe, 2230 Taylor St, San Francisco, CA, 94133",
#  "Pat's Cafe, 2330 Taylor St, San Francisco, CA, 94133",
#  "Paul's Deli, 10 Lombard St, San Francisco, CA, 94111",
#  'Pause, 1666 Market St, San Francisco, CA, 94102',
#  "Pearl's Deluxe Burgers, 708 Post St, San Francisco, CA, 94109",
#  'Penthouse Club & Restaurant, 412 Broadway St, San Francisco, CA, 94133',
#  'Per Diem, 43 Sutter St, San Francisco, CA, 94104',
#  'Perfect Hamburger, 601 Geary St, San Francisco, CA, 94102',
#  "Perry's, 155 Steuart St, San Francisco, CA, 94105",
#  "Perry's, 1944 Union St, San Francisco, CA, 94123",
#  "Perry's, SFO International Airport - Terminal 1, San Francisco, CA, 94128",
#  'Pesce, 2227 Polk St, San Francisco, CA, 94109',
#  "Pete's Deli and Cafe, 1661 Divisadero St, San Francisco, CA, 94115",
#  "Peter D's, 2201 Van Ness Ave, San Francisco, CA, 94109",
#  'Petit Cafe, 501 Geary St, San Francisco, CA, 94102',
#  'Phoenix Bar & Irish Gathering Place, 811 Valencia St, San Francisco, CA, 94110',
#  'Pier Market Seafood Restaurant, Pier 39, San Francisco, CA, 94133',
#  'Pinecrest Diner, 401 Geary St, San Francisco, CA, 94102',
#  'Pisces California Cuisine, 3414 Judah St, San Francisco, CA, 94122',
#  'Pizza Hut, 1523 Sloat Blvd, San Francisco, CA, 94132',
#  'Pizza Hut, 3349 Mission St, San Francisco, CA, 94110',
#  'Pizza Hut, 728 Geary St, San Francisco, CA, 94109',
#  'Pizza Joint, 2414 San Bruno Ave, San Francisco, CA, 94134',
#  'Pizza Prada, 239 Powell St, San Francisco, CA, 94102',
#  "Pizza Zone 'N Grill, 178 Valencia St, San Francisco, CA, 94103",
#  'Players, Pier 39, San Francisco, CA, 94133',
#  'Plouf, 40 Belden Pl, San Francisco, CA, 94104',
#  'Plow, 1299 18th St, San Francisco, CA, 94107',
#  "Pluto's, 3258 Scott St, San Francisco, CA, 94123",
#  "Pluto's, 627 Irving St, San Francisco, CA, 94122",
#  "Polker's Gourmet Burgers, 2226 Polk St, San Francisco, CA, 94109",
#  'Polo Grounds, 747 3rd St, San Francisco, CA, 94107',
#  'Pomelo, 1793 Church St, San Francisco, CA, 94131',
#  'Pomelo, 92 Judah St, San Francisco, CA, 94122',
#  'Popeyes Chicken & Biscuits, 1426t Fillmore St, San Francisco, CA, 94115',
#  'Popeyes Chicken & Biscuits, 2598 Mission St, San Francisco, CA, 94110',
#  'Popeyes Chicken & Biscuits, 599 Divisadero St, San Francisco, CA, 94117',
#  'Popeyes Chicken & Biscuits, 890 Geneva Ave, San Francisco, CA, 94112',
#  'Pork Store Cafe, 1451 Haight St, San Francisco, CA, 94117',
#  'Pork Store Cafe, 3122 16th St, San Francisco, CA, 94103',
#  'Portico, 98 1st St, San Francisco, CA, 94105',
#  'Posh Bagel, 4 Perry St, San Francisco, CA, 94107',
#  'Preet Palace, 1109 Fillmore, San Francisco, CA, 94115',
#  'Presidio Cafe, 300 Finley Rd, San Francisco, CA, 94129',
#  'Presidio Social Club, 563 Ruger St, San Francisco, CA, 94129',
#  'Prime Dip, 545A Sansome St, San Francisco, CA, 94115',
#  'Proper Food, 100 1st St, San Francisco, CA, 94105',
#  'Punjab, 2838 24th St, San Francisco, CA, 94110',
#  'Queen Malika, 4416 18 St, San Francisco, CA, 94114',
#  'Quickly, 5301 Mission St, San Francisco, CA, 94112',
#  'Quince, 470 Pacific Ave, San Francisco, CA, 94133',
#  'Quiznos Sub, 110 Bush St, San Francisco, CA, 94104',
#  'Quiznos Sub, 1501 Sloat Blvd, San Francisco, CA, 94132',
#  'Quiznos Sub, 215 Fremont St, San Francisco, CA, 94105',
#  'Quiznos Sub, 28 3rd St, San Francisco, CA, 94103',
#  'Quiznos Sub, 303 2nd St, San Francisco, CA, 94107',
#  'Quiznos Sub, 901 Polk St, San Francisco, CA, 94109',
#  'RN74, 301 Mission St, San Francisco, CA, 94105',
#  'Radish, 3465 19th St, San Francisco, CA, 94110',
#  'Radius, 1123 Folsom St, San Francisco, CA, 94103',
#  'Rainforest Cafe, 145 Jefferson St, San Francisco, CA, 94133',
#  'Red Dog, 303 2nd St, San Francisco, CA, 94107',
#  'Red Door Cafe, 1608 Bush St, San Francisco, CA, 94108',
#  "Red's Java House, Pier 30, San Francisco, CA, 94105",
#  'Redford, 673 Geary St, San Francisco, CA, 94102',
#  'Restaurant Gary Danko, 800 N Point St, San Francisco, CA, 94109',
#  'Restaurant Seven Fifty (750), 750 Kearny St, San Francisco, CA, 94108',
#  "Rhea's Cafe, 2200 Bryant St, San Francisco, CA, 94110",
#  "Rhea's Deli, 800 Valencia St, San Francisco, CA, 94110",
#  'Rich Table, 199 Gough St, San Francisco, CA, 94102',
#  'Rickybobby, 400 Haight St, San Francisco, CA, 94102',
#  'Rigolo, 3465 California St, San Francisco, CA, 94118',
#  "Roady's Longburger, 101 Spear St, San Francisco, CA, 94105",
#  'Roam Artisan Burgers, 1785 Union St, San Francisco, CA, 94123',
#  'Robber Baron, 2032 Polk St, San Francisco, CA, 94109',
#  'Rogue Ales Public House, 673 Union St, San Francisco, CA, 94133',
#  'Rosamunde Sausage Grill, 2832 Mission St, San Francisco, CA, 94110',
#  'Rosamunde Sausage Grill, 545 Haight St, San Francisco, CA, 94117',
#  'Rosenberg Deli and Market, 276 Noe St, San Francisco, CA, 94114',
#  'Rosenburg Deli, 276 Noe St, San Francisco, CA, 94114',
#  "Rossi's Delicatessen, 426 Castro St, San Francisco, CA, 94114",
#  'Rouge et Blanc, 334 Grant Ave, San Francisco, CA, 94108',
#  'Round Table Pizza, 2660 San Bruno Ave, San Francisco, CA, 94134',
#  'Roxanne Cafe, 570 Powell St, San Francisco, CA, 94108',
#  "Rubio's, 865 Market St, San Francisco, CA, 94103",
#  'Ruby Skye, 420 Mason St, San Francisco, CA, 94102',
#  'Rue Lepic, 900 Pine St, San Francisco, CA, 94108',
#  'Rye Project, 180 7th St, San Francisco, CA, 94103',
#  'S & R Lounge, 55 5th St, San Francisco, CA, 94103',
#  "S.F. Preet's Cafe, 995 Market St, San Francisco, CA, 94103",
#  'SPQR, 1911 Fillmore St, San Francisco, CA, 94115',
#  'Saigon Deli Express, 50 Drumm St, San Francisco, CA, 94105',
#  'Salt House, 545 Mission St, San Francisco, CA, 94105',
#  'Salumeria, 1550 Bryant St, San Francisco, CA, 94103',
#  'Salumeria, 3000 20th St, San Francisco, CA, 94110',
#  "Sammy's Gourmet Deli & Cafe, 1356 Van Ness Ave, San Francisco, CA, 94109",
#  "Sammy's on 2nd, 84 2nd St, San Francisco, CA, 94105",
#  'Sauce, 131 Gough St, San Francisco, CA, 94102',
#  'Sauce, 56 Belden Pl, San Francisco, CA, 94104',
#  'Savor, 3913 24th St, San Francisco, CA, 94114',
#  'Sbarro, 3521 20th St, San Francisco, CA, 94110',
#  'Schilling Cafe, 667-669 Commercial St, San Francisco, CA, 94111',
#  "Schmidt's, 2400 Folsom St, San Francisco, CA, 94110",
#  "Schroeder's, 240 Front St, San Francisco, CA, 94111",
#  'Sea Breeze Cafe, 3940 Judah St, San Francisco, CA, 94122',
#  'Seaglass, Pier 15, San Francisco, CA, 94111',
#  'Seal Rock Inn Restaurant, 545 Point Lobos Ave, San Francisco, CA, 94121',
#  'Sears Fine Food, 439 Powell St, San Francisco, CA, 94102',
#  'Sheba Piano Lounge, 1419 Fillmore St, San Francisco, CA, 94115',
#  "Shorty Goldstein's, 126 Sutter St, San Francisco, CA, 94104",
#  'Show Dogs, 1020 Market Street, San Francisco, CA, 94102',
#  'Silver Clouds, 1994 Lombard St, San Francisco, CA, 94123',
#  "Sinbad's, Pier 2 Embarcadero St, San Francisco, CA, 94111",
#  'Slow Club, 2501 Mariposa St, San Francisco, CA, 94110',
#  'SmashBurger, 2300 16th St, San Francisco, CA, 94103',
#  "Smokin' Warehouse, Location Varies, San Francisco, CA, 94107",
#  'SoMa Inn Cafe, 1082 Folsom St, San Francisco, CA, 94103',
#  'Soccer Cafe, 2797 16th St, San Francisco, CA, 94103',
#  'Social Kitchen & Brewery, 1326 9th Ave, San Francisco, CA, 94122',
#  'Soma Eats, 186 2nd St, San Francisco, CA, 94105',
#  'Sons & Daughters, 708 Bush St, San Francisco, CA, 94108',
#  'Sorrento Delicatessen, 4763 Mission St , San Francisco, CA, 94112',
#  'South End Grill & Bar, 1499 Valencia St, San Francisco, CA, 94110',
#  'South Park Cafe, 108 S Park St, San Francisco, CA, 94107',
#  'Southern Pacific Brewing Company, 620 Treat Ave, San Francisco, CA, 94110',
#  'Sparrow, 1640 Haight St, San Francisco, CA, 94117',
#  'Spinnerie, 1401 Polk St, San Francisco, CA, 94109',
#  'Split Pea Seduction, 138 6th St, San Francisco, CA, 94103',
#  'Spruce, 3640 Sacramento St, San Francisco, CA, 94118',
#  'Squat & Gobble, 2263 Chestnut St, San Francisco, CA, 94123',
#  'Squat & Gobble, 3600 16th St, San Francisco, CA, 94114',
#  'St. Vincent, 1270 Valencia St, San Francisco, CA, 94110',
#  'Stacks, 501 Hayes St, San Francisco, CA, 94102',
#  'Starbelly, 3583 16th St, San Francisco, CA, 94114',
#  'Starbucks Coffee, 100 W Portal Ave, San Francisco, CA, 94127',
#  'Starbucks Coffee, 120 4th St, San Francisco, CA, 94103',
#  'Starbucks Coffee, 1231 Market St, San Francisco, CA, 94103',
#  'Starbucks Coffee, 1255 Battery St, San Francisco, CA, 94111',
#  'Starbucks Coffee, 1298 Howard St, San Francisco, CA, 94103',
#  'Starbucks Coffee, 1390 Market St, San Francisco, CA, 94102',
#  'Starbucks Coffee, 1401 Van Ness Ave, San Francisco, CA, 94109',
#  'Starbucks Coffee, 1501 Fillmore St, San Francisco, CA, 94115',
#  'Starbucks Coffee, 1750 Divisadero St, San Francisco, CA, 94115',
#  'Starbucks Coffee, 1799 Fulton St, San Francisco, CA, 94117',
#  'Starbucks Coffee, 1800 Irving St, San Francisco, CA, 94122',
#  'Starbucks Coffee, 1899 Union St, San Francisco, CA, 94123',
#  'Starbucks Coffee, 201 3rd St, San Francisco, CA, 94103',
#  'Starbucks Coffee, 201 Powell St, San Francisco, CA, 94102',
#  'Starbucks Coffee, 210 Spear St, San Francisco, CA, 94105',
#  'Starbucks Coffee, 2132 Chestnut St, San Francisco, CA, 94123',
#  'Starbucks Coffee, 2165 Polk St, San Francisco, CA, 94109',
#  'Starbucks Coffee, 222 Mason St, San Francisco, CA, 94102',
#  'Starbucks Coffee, 2222 Fillmore St, San Francisco, CA, 94115',
#  'Starbucks Coffee, 2300 16th St, San Francisco, CA, 94103',
#  'Starbucks Coffee, 2435 California St, San Francisco, CA, 94115',
#  'Starbucks Coffee, 27 Drumm St, San Francisco, CA, 94111',
#  'Starbucks Coffee, 2727 Mariposa St, San Francisco, CA, 94110',
#  'Starbucks Coffee, 280 King St, San Francisco, CA, 94107',
#  'Starbucks Coffee, 295 California St, San Francisco, CA, 94111',
#  'Starbucks Coffee, 3251 20th Ave, San Francisco, CA, 94132',
#  'Starbucks Coffee, 350 Parnassus Ave, San Francisco, CA, 94117',
#  'Starbucks Coffee, 359 Grant Ave, San Francisco, CA, 94108',
#  'Starbucks Coffee, 3595 California St, San Francisco, CA, 94118',
#  'Starbucks Coffee, 36 2nd St, San Francisco, CA, 94105',
#  'Starbucks Coffee, 3735 Buchanan St, San Francisco, CA, 94123',
#  'Starbucks Coffee, 390 Stockton St, San Francisco, CA, 94108',
#  'Starbucks Coffee, 398 Market St, San Francisco, CA, 94111',
#  'Starbucks Coffee, 3995 24th St, San Francisco, CA, 94114',
#  'Starbucks Coffee, 4094 18th St, San Francisco, CA, 94114',
#  'Starbucks Coffee, 425 Battery St, San Francisco, CA, 94111',
#  'Starbucks Coffee, 44 Montgomery St, San Francisco, CA, 94104',
#  'Starbucks Coffee, 442 Geary St, San Francisco, CA, 94102',
#  'Starbucks Coffee, 490 Brannan St, San Francisco, CA, 94107',
#  'Starbucks Coffee, 499 Bay St, San Francisco, CA, 94133',
#  'Starbucks Coffee, 52 California St, San Francisco, CA, 94111',
#  'Starbucks Coffee, 5290 Diamond Heights Blvd, San Francisco, CA, 94131',
#  'Starbucks Coffee, 555 California St, San Francisco, CA, 94104',
#  'Starbucks Coffee, 675 Portola Dr, San Francisco, CA, 94127',
#  'Starbucks Coffee, 680 Beach St, San Francisco, CA, 94109',
#  'Starbucks Coffee, 689 Townsend St, San Francisco, CA, 94103',
#  'Starbucks Coffee, 701 Battery St, San Francisco, CA, 94111',
#  'Starbucks Coffee, 74 New Montgomery St, San Francisco, CA, 94105',
#  'Starbucks Coffee, 744 Irving St, San Francisco, CA, 94122',
#  'Starbucks Coffee, 780 Market St, San Francisco, CA, 94102',
#  'Starbucks Coffee, 865 Market St, San Francisco, CA, 94103',
#  'Starbucks Coffee, 99 Jackson St, San Francisco, CA, 94111',
#  'Starvin Marvin, 932 Geneva Ave, San Francisco, CA, 94112',
#  'State Bird Provisions, 1529 Fillmore St, San Francisco, CA, 94115',
#  'Steep Brew, 450 Rhode Island St, San Francisco, CA, 94103',
#  'Steins, 731 Clement St, San Francisco, CA, 94118',
#  'Stem, 499 Illinois St, San Francisco, CA, 94158',
#  'Stock in Trade, 2036 Lombard St, San Francisco, CA, 94123',
#  'Stones Throw, 1896 Hyde St, San Francisco, CA, 94109',
#  'Straw, 203 Octavia Blvd, San Francisco, CA, 94102',
#  'Street, 2141 Polk St, San Francisco, CA, 94109',
#  'Stuffed, 2788 Mission St, San Francisco, CA, 94110',
#  'Subway, 408 Montgomery St., San Francisco, CA, 94104',
#  'Subway, 423 Bush St, San Francisco, CA, 94108',
#  'Subway, 483 Sacramento St, San Francisco, CA, 94104',
#  'Sugar Bowl Bakery, 2238 Geary Blvd, San Francisco, CA, 94115',
#  'Sugar Bowl Bakery, 2623 San Bruno Ave, San Francisco, CA, 94134',
#  'Sunrise Cafe, 1114 Bryant St, San Francisco, CA, 94103',
#  'Super Duper, 2304 Market St, San Francisco, CA, 94114',
#  'Suppenkuche, 525 Laguna St, San Francisco, CA, 94102',
#  'Supperclub, 657 Harrison St, San Francisco, CA, 94107',
#  'Sutter Pub, 700 Sutter St, San Francisco, CA, 94109',
#  'Sweet Woodruff, 798 Sutter St, San Francisco, CA, 94109',
#  'Sweetmue, 3414 22nd St, San Francisco, CA, 94110',
#  "Swensen's, Union Hyde, San Francisco, CA, 94102",
#  "T'Licious Delicatessens, 431 23rd Ave, San Francisco, CA, 94121",
#  "T.G.I. Friday's, 25 Van Ness Ave, San Francisco, CA, 94102",
#  'TAP415, 845 Market St, San Francisco, CA, 94103',
#  'TBD, 1077 Mission St, San Francisco, CA, 94103',
#  'TJ Cafe, 724 La Playa St, San Francisco, CA, 94121',
#  'Tadich Grill, 240 California St, San Francisco, CA, 94111',
#  'Tapioca Express, 1522 Fillmore St, San Francisco, CA, 94115',
#  'Taps, 1516 Broadway, San Francisco, CA, 94111',
#  "Tarantino's Restaurant, 206 Jefferson St, San Francisco, CA, 94133",
#  'Tartine Bakery, 600 Guerrero St, San Francisco, CA, 94110',
#  'Tartine Cafe Francais, 244 Gough St, San Francisco, CA, 94102',
#  'Taverna Aventine, 582 Washington St, San Francisco, CA, 94111',
#  'Teaway, 2250 Irving St, San Francisco, CA, 94122',
#  "Ted's Market, 1530 Howard St, San Francisco, CA, 94103",
#  "Ted's Sports Bar & Grill, 312 Harriet St, San Francisco, CA, 94103",
#  'Tee Off Bar and Grill, 3129 Clement St, San Francisco, CA, 94121',
#  'Tempest, 431 Natoma St, San Francisco, CA, 94103',
#  'Tender, 854 Geary St, San Francisco, CA, 94109',
#  'Tender Greens, 30 Fremont St, San Francisco, CA, 94105',
#  'Tennessee Grill, 1128 Taraval St, San Francisco, CA, 94116',
#  'Terrace Cafe, 1 Zoo Rd, San Francisco, CA, 94132',
#  'The Alembic, 1725 Haight St, San Francisco, CA, 94117',
#  'The American Grilled Cheese Kitchen, 1 South Park, San Francisco, CA, 94107',
#  'The Aveline, 490 Geary St, San Francisco, CA, 94102',
#  'The Bell Tower, 1900 Polk St, San Francisco, CA, 94109',
#  'The Bitter End, 441 Clement St, San Francisco, CA, 94118',
#  'The Blue Plate, 3218 Mission St, San Francisco, CA, 94110',
#  "The Boy's Deli, 2222 Polk St, San Francisco, CA, 94109",
#  'The Brazen Head, 3166 Buchanan St, San Francisco, CA, 94123',
#  'The Brick Yard Restaurant & Bar, 1787 Union St, San Francisco, CA, 94123',
#  'The Bubble Lounge, 714 Montgomery St, San Francisco, CA, 94111',
#  'The Burritt Room + Burritt Tavern, 417 Stockton St, San Francisco, CA, 94108',
#  'The Butler & The Chef Bistro, 155 South Park St, San Francisco, CA, 94107',
#  'The Chameleon, 1299 Pacific Ave, San Francisco, CA, 94109',
#  'The Cheesecake Factory, 251 Geary St, San Francisco, CA, 94102',
#  'The Cliff House Bistro, 1090 Point Lobos Ave, San Francisco, CA, 94121',
#  'The Commissary, 101 Montgomery St, San Francisco, CA, 94129',
#  'The Corner Store, 5 Masonic Ave, San Francisco, CA, 94118',
#  'The Cravery, 829 Mission St, San Francisco, CA, 94103',
#  'The Crepe Cafe, Pier 39, San Francisco, CA, 94133',
#  'The Crepe House, 1132 Valencia St, San Francisco, CA, 94110',
#  'The Crepe House, 1755 Polk St, San Francisco, CA, 94109',
#  'The European, 490 Geary St, San Francisco, CA, 94102',
#  'The Front Room, 1500 California St, San Francisco, CA, 94109',
#  'The Garden Court, 2 New Montgomery St, San Francisco, CA, 94105',
#  'The Great Steak and Potato Company, 3251 20th Ave, San Francisco, CA, 94132',
#  'The Grill, 799 Bryant St, San Francisco, CA, 94107',
#  'The Grind Cafe, 783 Haight St, San Francisco, CA, 94117',
#  'The Grove Cafe Yerba Buena, 690 Mission St, San Francisco, CA, 94105',
#  'The Grove Fillmore, 2016 Fillmore St, San Francisco, CA, 94115',
#  'The Holding Company, 2 Embarcadero Ctr, San Francisco, CA, 94111',
#  'The Italian Homemade Company, 716 Columbus Ave, San Francisco, CA, 94133',
#  'The Jewel Restaurant, 5251 3rd St, San Francisco, CA, 94124',
#  'The Liberties, 998 Guerrero St, San Francisco, CA, 94110',
#  'The Living Room, 181 3rd St, San Francisco, CA, 94105',
#  'The Lost Ladles Cafe, 655 Montgomery St, San Francisco, CA, 94111',
#  'The Matterhorn Swiss Restaurant, 2323 Van Ness Ave, San Francisco, CA, 94109',
#  'The Melt, 115 New Montgomery St, San Francisco, CA, 94105',
#  'The Mortimer, 550 Geary St, San Francisco, CA, 94102',
#  'The Oak Room, 335 Powell St, San Francisco, CA, 94102',
#  'The Pied Piper, 2 New Montgomery St, San Francisco, CA, 94105',
#  'The Plant, Pier 3, Embarcadero, San Francisco, CA, 94111',
#  'The Progress, 1525 Fillmore St, San Francisco, CA, 94115',
#  'The Pub, 851 Beach St, San Francisco, CA, 94133',
#  'The Ramp, 855 Terry Francois St, San Francisco, CA, 94107',
#  'The Rite Spot Cafe, 2099 Folsom St, San Francisco, CA, 94110',
#  'The Rotunda, 150 Stockton St, San Francisco, CA, 94108',
#  'The Royal Exchange, 301 Sacramento St, San Francisco, CA, 94111',
#  'The Royale, 800 Post St, San Francisco, CA, 94109',
#  'The Sandwich Company, 220 Bush St, San Francisco, CA, 94104',
#  'The Seismic Joint, Pier 15, San Francisco, CA, 94111',
#  'The Sentinel, 37 New Montgomery St, San Francisco, CA, 94105',
#  'The Showroom, 1000 Van Ness Ave, San Francisco, CA, 94109',
#  'The Social Study, 1795 Geary St, San Francisco, CA, 94109',
#  'The Square, 1707 Powell St, San Francisco, CA, 94133',
#  'The Taco Guys, Location Varies, San Francisco, CA, 94111',
#  'The Terrace, 55 Music Concourse Dr, San Francisco, CA, 94118',
#  'The Tipsy Pig, 2231 Chestnut St, San Francisco, CA, 94123',
#  'The Tradesman, 753 Alabama St, San Francisco, CA, 94110',
#  'The Vestry, 777 Valencia St, San Francisco, CA, 94110',
#  'The View Cafe, 3333 California St, San Francisco, CA, 94118',
#  'The View Lounge, 780 Mission St, San Francisco, CA, 94103',
#  'The Westwood, 1152 Valencia St, San Francisco, CA, 94110',
#  'The Willows, 1582 Folsom St, San Francisco, CA, 94103',
#  'Thermidor, 8 Mint Plaza, San Francisco, CA, 94103',
#  'Ti-couz - CLOSED, 3108 16th St, San Francisco, CA, 94103',
#  'Tipsy Cow, 15005 Ventura Blvd, Sherman Oaks, CA, 94103',
#  'Toast, 1601 Polk St, San Francisco, CA, 94109',
#  'Toast Eatery, 1748 Church St, San Francisco, CA, 94131',
#  'Toasties, 836 Irving St, San Francisco, CA, 94122',
#  "Tony Baloney's, 1098 Howard St, San Francisco, CA, 94103",
#  'Tony Romas, 2 Perry St, San Francisco, CA, 94107',
#  "Tony's Cable Car Restaurant, 2500 Geary Blvd, San Francisco, CA, 94115",
#  'Tower Burger, 729 Portola Dr, San Francisco, CA, 94127',
#  'Town Hall, 342 Howard St, San Francisco, CA, 94105',
#  "Town's End Restaurant & Bakery, 2 Townsend St, San Francisco, CA, 94107",
#  'Trace, 181 3rd St, San Francisco, CA, 94103',
#  'Trick Dog, 3010 20th St, San Francisco, CA, 94110',
#  'Triptych, 1155 Folsom St, San Francisco, CA, 94103',
#  'Trolley Caffe, 1400 Taraval St, San Francisco, CA, 94116',
#  'Trou Normand, 140 New Montgomery St, San Francisco, CA, 94105',
#  "Tully's Coffee, 3966 24th St, San Francisco, CA, 94114",
#  'Two Jacks Seafood, 401 Haight St, San Francisco, CA, 94117',
#  'Two Sisters Bar And Books, 579 Hayes St, San Francisco, CA, 94102',
#  "Tyger's Coffee Shop, 2798 Diamond St, San Francisco, CA, 94131",
#  'Ultra Crepes, Location Varies, San Francisco, CA, 94102',
#  'Umami Burger, 2184 Union St, San Francisco, CA, 94123',
#  "Uncle Boy's, 245 Balboa St, San Francisco, CA, 94118",
#  'Union Larder, 1945 Hyde St, San Francisco, CA, 94109',
#  'Universal Cafe, 2814 19th St, San Francisco, CA, 94110',
#  'Upcider, 1160 Polk St, San Francisco, CA, 94109',
#  'Urban Putt, 1096 S Van Ness Ave, San Francisco, CA, 94110',
#  'Urchin Bistrot, 584 Valencia St, San Francisco, CA, 94110',
#  'V Cafe, 1525 Folsom St, San Francisco, CA, 94107',
#  'VIP Coffee & Cakes Shop, 671 Broadway, San Francisco, CA, 94133',
#  'Velvet Room, 495 Geary St, San Francisco, CA, 94102',
#  'Verbena, 2323 Polk St, San Francisco, CA, 94109',
#  'Victory Hall, 360 Ritch St, San Francisco, CA, 94107',
#  'Vinyl, 359 Divisidero St, San Francisco, CA, 94117',
#  'Vitrine, 125 3rd St, San Francisco, CA, 94103',
#  'Voodoo Van, Location Varies, San Francisco, CA, 94103',
#  'Walzwerk, 381 S Van Ness Ave, San Francisco, CA, 94103',
#  "Wendy's Cheesecake Bakery, 4942 3rd St, San Francisco, CA, 94124",
#  "Wexler's, 568 Sacramento St, San Francisco, CA, 94111",
#  'Whisk On Wheels, Location Varies, San Francisco, CA, 94105',
#  'Whiz Burgers, 700 S Van Ness Ave, San Francisco, CA, 94110',
#  'Wild Hare, 2801 California St, San Francisco, CA, 94115',
#  ...]

# %%
drop_list = ['J Shack, Location Varies, San Francisco, CA, 94103',"Sinbad's, Pier 2 Embarcadero St, San Francisco, CA, 94111",'Triptych, 1155 Folsom St, San Francisco, CA, 94103']
name_and_addr_list_new = [x for x in name_and_addr_list if x not in drop_list]

drop_list = ['J Shack',"Sinbad's",'Triptych']
restaurant_name_list_new = [x for x in restaurant_name_list if x not in drop_list]

name_and_addr_list_split = [x.split(', ',1) for x in name_and_addr_list_new]

# %%
print len(restaurant_name_list_new)
print len(name_and_addr_list_new)
print len(name_and_addr_list_split)
# Out:
# 1012
# 1012
# 1012

# %%
test_idx = -1
print restaurant_name_list_new[test_idx]
print name_and_addr_list_new[test_idx]
print name_and_addr_list_split[test_idx]
# Out:
# yoCup
# yoCup, 685 Market St, San Francisco, CA, 94105
# ['yoCup', '685 Market St, San Francisco, CA, 94105']

# %%
tfidf_mat_menus_new = tfIdfMatCreator(new_tokens_new)

# %%
tfidf_mat_menus_new
# Out:
# <75105x9658 sparse matrix of type '<type 'numpy.float64'>'
# 	with 559901 stored elements in Compressed Sparse Row format>

# %% [markdown]
# # Pickle everything important

# %%
pickle.dump(name_and_addr_list_new, open( "name_and_addr_list_new.p", "wb" ) )
pickle.dump(name_and_addr_list_split, open( "name_and_addr_list_split.p", "wb" ) )
pickle.dump(tfidf_mat_menus_new, open( "tfidf_mat_menus_new.p", "wb" ) )
all_menus_new.to_pickle('all_menus_new.p')
